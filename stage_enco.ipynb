# %% [markdown]
# #### Сеть энкодер для стейджинга

# %%
import os
import sys
import time
import numpy as np

import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

from tqdm import tqdm

from jaw_gen3d_3lm import Landmark_gen
from csv_parser_pd_ver2 import set_gen_fr_csv_pd_ver3
from models import get_autoencoder

from torch.utils.tensorboard import SummaryWriter

# %%
# run tensorboard: tensorboard --logdir=runs
# NOTE!!! перед стартом tensrboard удалить все данные из папки
# runs от предыдущих запусков. иначе ничего не запускается.

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# device = "cpu"

# количество зубов в обоих челюстях, всегда работаем с обеими сразу
n_teeth = 16*2
landmarks_data_len = 15     # количество значений лендмарок = 5*3 одного зуба
inp_dim = 480               # длина вектора входных значений 
code_dim = inp_dim//6       # размер скрытого слоя энкодера
batch_size = None

# csv_fpath = r"C:\Projects\torchEncoder\csv\11k.csv" # main for training now loads 5 min
# csv_fpath = r"C:\Projects\torchEncoder\csv\diego_landmarks_over_900.csv" # main for training now loads 5 min
# csv_fpath = r"D:\Nick_cases\landmarks.csv"
# csv_fpath = r"C:\Projects\torchEncoder\csv\11k_head.csv"
csv_fpath = r"C:\Projects\torchEncoder\csv\Diego_1k.csv"

models_dir = "models"
dataloadersDir = 'dataLoaders'
# dir for save libtorch models ( *.pt )
libtorch_models_dir = "libtorch_models"

epochs = 3000
train_mode = (False, True)[1]
# creates new dataloaders from csv
create_new_DataLoaders = (False, True)[0]

# создадим директорию для либторч моделей если ее нет
if not os.path.isdir(libtorch_models_dir):
    os.mkdir(libtorch_models_dir)

# то же для даталоадеров
if not os.path.isdir(dataloadersDir):
    os.mkdir(dataloadersDir)

print(f"{'train mode' if train_mode else 'test mode'} ")
print(f"{'new dataLoaders will be created from csv' if create_new_DataLoaders else 'Existing Dataloaders will be used'}")
# Out:
# Using cuda device
# train mode
# Existing Dataloaders will be used

# %% [markdown]
# берем данные из файла csv

# %%
# сохраняем данные в даталодыре, если челюсти по отдельности, то проходим 2 раза
# если вместе, то один.

base_path = os.getcwd()  # c:\Projects\jaw_encoder
if create_new_DataLoaders:  # means create new pth files from csv then
    # use that files to load Dataloader from them
    print(f"Loading from {csv_fpath}")
    # выбираем данные из файла
    # формат [([<210>T1], [<210>T2]), <next case tuple>, <next...>, ...]
    # делаем сразу для двух челюстей - 2 пары даталоадеров и сразу их сохраняем.
    # потом для работы выбираем нужный, подгружая его из pth

    # формируем датасеты из файла csv
    dataset = set_gen_fr_csv_pd_ver3(csv_fpath)
    # print(f"dataset dw jaw len {len(dataset_dw_jaw)}   dataset up jaw len {len(dataset_up_jaw)}")
    print(f"\nData loaded from csv")
    print(f"dataset len = {len(dataset)}")
    # разобьем датасет на тренировочную и тестовую части
    data_len = len(dataset)
    set_divider_ = round(data_len*0.9)

    train = dataset[:set_divider_]
    test = dataset[set_divider_:]

    print(f"length train / val    =    {len(train)} / {len(test)} ")

    batch_size = 128
    # делаем DataLoader
    # шафлить только в трейне
    train_loader = DataLoader(train, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test, batch_size=batch_size, shuffle=False)

    # ''' save dataloader as a pth files separately for Upper and Down Jaws'''
    if not os.path.isdir(dataloadersDir):
        os.mkdir(dataloadersDir)

    torch.save(train_loader,    f'{dataloadersDir}/train_loader.pth')
    torch.save(test_loader,     f'{dataloadersDir}/test_loader.pth')
    print(f"Dataloaders saved in {dataloadersDir} folder")

# %%
# always load dataloaders from pth files
train_loader_path = f'{dataloadersDir}/train_loader.pth'
test_loader_path = f'{dataloadersDir}/test_loader.pth'
assert os.path.isfile(train_loader_path), "train dataloader file not found"
assert os.path.isfile(test_loader_path), "test dataloader file not found"

train_loader = torch.load(train_loader_path)
# train_loader.train_data.to(torch.device("cuda"))
test_loader = torch.load(test_loader_path)
batch_size = train_loader.batch_size
print(f"All data loaded successfilly")
print(f"train_loader_path = {train_loader_path}")
print(f"test_Loader_path = {test_loader_path}")
# Out:
# All data loaded successfilly
# train_loader_path = dataLoaders/train_loader.pth
# test_Loader_path = dataLoaders/test_loader.pth

# %%
assert batch_size, 'batch_size is not set'
learning_rate = 1e-3
# loss_fn = nn.MSELoss()
# loss_fn = nn.CrossEntropyLoss()

# create model
# model = nn.Transformer(inp_dim).to(device)  # nhead=16, num_encoder_layers=12)
model = get_autoencoder(inp_dim, code_dim, stages=1).to(device)
# criterion = nn.NLLLoss()
criterion = nn.MSELoss()

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
loss_min = [1e10]
device
# Out:
# 'cuda'

# %%
# train transformer
best_test_loss = [None, ]
def train_loop(epoch):
    # model = torch.load("models/ep3000_17.48.pth").to(device)
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    # ntokens = 61440 # len(train_loader) ??
    loss = 0.
    loss_test = 0.0
    # for batch, i in enumerate(range(0, train_data.size(0) - 1, args.bptt)):
    for batch, (X, y) in enumerate(train_loader):
        
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        model.zero_grad()
        # optimizer.zero_grad()
        
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        # output.forward
        
        # Backpropagation
        loss = criterion(output, y)
        loss.backward()
        loss = loss.item()
        writer.add_scalar("Loss/train", loss, epoch)
        optimizer.step()
        
    # evaluating
    model.eval()
    with torch.no_grad():
        for batch_test, (X, y) in enumerate(test_loader):
            
            X = X.to(device)
            y = y.to(device)

            output = model(X)
            
            loss_test = criterion(output, y)
            loss_test = loss_test.item()
            writer.add_scalar("Loss/val", loss_test, epoch)

    # Save the model if the validation loss is the best we've seen so far.
    if not best_test_loss[0] or loss_test < best_test_loss[0]:
        #with open("models", 'wb') as f:
        if loss_test<1.938:
            torch.save(model, f"models/ep{epoch}_{loss_test:.4}.pth")
        best_test_loss[0] = loss_test
    if epoch%500 ==0:
        #if epoch%1000==0:
        optimizer.param_groups[0]['lr'] /= 2
        print(f"!!!!!!!!!!!!!!!cahnge lr to` {optimizer.param_groups[0]['lr']}")

    print(f"Epoch {epoch} - loss {loss:.5}  /  val loss {loss_test:.5} lr = {optimizer.param_groups[-1]['lr']} grs = {len(optimizer.param_groups)} ")

# %%
# train all
transfer_learning = 0
if transfer_learning:
    model = torch.load(r"trans1.pth")

if train_mode:
    writer = SummaryWriter()  # writes data for tensorboard default logdir=runs
    for epoch in range(1, epochs+1):
        train_loop(epoch)
    print("Training done!")
    writer.flush()
# Out:
# Epoch 1 - loss 191.47  /  val loss 178.65 lr = 0.001 grs = 1
# Epoch 2 - loss 180.93  /  val loss 147.57 lr = 0.001 grs = 1
# Epoch 3 - loss 149.87  /  val loss 94.761 lr = 0.001 grs = 1
# Epoch 4 - loss 96.892  /  val loss 77.436 lr = 0.001 grs = 1
# Epoch 5 - loss 78.654  /  val loss 44.03 lr = 0.001 grs = 1
# Epoch 6 - loss 45.868  /  val loss 27.197 lr = 0.001 grs = 1
# Epoch 7 - loss 29.733  /  val loss 26.694 lr = 0.001 grs = 1
# Epoch 8 - loss 29.578  /  val loss 24.754 lr = 0.001 grs = 1
# Epoch 9 - loss 27.813  /  val loss 26.165 lr = 0.001 grs = 1
# Epoch 10 - loss 29.26  /  val loss 27.259 lr = 0.001 grs = 1
# Epoch 11 - loss 30.324  /  val loss 23.545 lr = 0.001 grs = 1
# Epoch 12 - loss 26.612  /  val loss 22.534 lr = 0.001 grs = 1
# Epoch 13 - loss 25.585  /  val loss 22.463 lr = 0.001 grs = 1
# Epoch 14 - loss 25.451  /  val loss 20.773 lr = 0.001 grs = 1
# Epoch 15 - loss 23.65  /  val loss 19.71 lr = 0.001 grs = 1
# Epoch 16 - loss 22.416  /  val loss 20.271 lr = 0.001 grs = 1
# Epoch 17 - loss 22.814  /  val loss 19.28 lr = 0.001 grs = 1
# Epoch 18 - loss 21.8  /  val loss 17.944 lr = 0.001 grs = 1
# Epoch 19 - loss 20.549  /  val loss 18.026 lr = 0.001 grs = 1
# Epoch 20 - loss 20.702  /  val loss 17.764 lr = 0.001 grs = 1
# Epoch 21 - loss 20.449  /  val loss 16.966 lr = 0.001 grs = 1
# Epoch 22 - loss 19.601  /  val loss 17.029 lr = 0.001 grs = 1
# Epoch 23 - loss 19.596  /  val loss 17.231 lr = 0.001 grs = 1
# Epoch 24 - loss 19.792  /  val loss 16.569 lr = 0.001 grs = 1
# Epoch 25 - loss 19.213  /  val loss 16.374 lr = 0.001 grs = 1
# Epoch 26 - loss 19.126  /  val loss 16.505 lr = 0.001 grs = 1
# Epoch 27 - loss 19.304  /  val loss 16.168 lr = 0.001 grs = 1
# Epoch 28 - loss 18.945  /  val loss 16.022 lr = 0.001 grs = 1
# Epoch 29 - loss 18.74  /  val loss 16.183 lr = 0.001 grs = 1
# Epoch 30 - loss 18.852  /  val loss 15.901 lr = 0.001 grs = 1
# Epoch 31 - loss 18.573  /  val loss 15.594 lr = 0.001 grs = 1
# Epoch 32 - loss 18.296  /  val loss 15.585 lr = 0.001 grs = 1
# Epoch 33 - loss 18.293  /  val loss 15.369 lr = 0.001 grs = 1
# Epoch 34 - loss 18.03  /  val loss 15.123 lr = 0.001 grs = 1
# Epoch 35 - loss 17.695  /  val loss 15.095 lr = 0.001 grs = 1
# Epoch 36 - loss 17.575  /  val loss 14.808 lr = 0.001 grs = 1
# Epoch 37 - loss 17.241  /  val loss 14.411 lr = 0.001 grs = 1
# Epoch 38 - loss 16.827  /  val loss 14.186 lr = 0.001 grs = 1
# Epoch 39 - loss 16.562  /  val loss 13.795 lr = 0.001 grs = 1
# Epoch 40 - loss 16.079  /  val loss 13.436 lr = 0.001 grs = 1
# Epoch 41 - loss 15.594  /  val loss 13.141 lr = 0.001 grs = 1
# Epoch 42 - loss 15.191  /  val loss 12.64 lr = 0.001 grs = 1
# Epoch 43 - loss 14.622  /  val loss 12.341 lr = 0.001 grs = 1
# Epoch 44 - loss 14.257  /  val loss 11.949 lr = 0.001 grs = 1
# Epoch 45 - loss 13.764  /  val loss 11.728 lr = 0.001 grs = 1
# Epoch 46 - loss 13.445  /  val loss 11.415 lr = 0.001 grs = 1
# Epoch 47 - loss 13.088  /  val loss 11.109 lr = 0.001 grs = 1
# Epoch 48 - loss 12.763  /  val loss 10.819 lr = 0.001 grs = 1
# Epoch 49 - loss 12.415  /  val loss 10.563 lr = 0.001 grs = 1
# Epoch 50 - loss 12.084  /  val loss 10.256 lr = 0.001 grs = 1
# Epoch 51 - loss 11.745  /  val loss 9.9793 lr = 0.001 grs = 1
# Epoch 52 - loss 11.485  /  val loss 9.7561 lr = 0.001 grs = 1
# Epoch 53 - loss 11.238  /  val loss 9.6151 lr = 0.001 grs = 1
# Epoch 54 - loss 11.049  /  val loss 9.4384 lr = 0.001 grs = 1
# Epoch 55 - loss 10.865  /  val loss 9.2716 lr = 0.001 grs = 1
# Epoch 56 - loss 10.714  /  val loss 9.0998 lr = 0.001 grs = 1
# Epoch 57 - loss 10.534  /  val loss 8.967 lr = 0.001 grs = 1
# Epoch 58 - loss 10.375  /  val loss 8.8199 lr = 0.001 grs = 1
# Epoch 59 - loss 10.222  /  val loss 8.6377 lr = 0.001 grs = 1
# Epoch 60 - loss 10.05  /  val loss 8.4985 lr = 0.001 grs = 1
# Epoch 61 - loss 9.8969  /  val loss 8.3525 lr = 0.001 grs = 1
# Epoch 62 - loss 9.7298  /  val loss 8.1761 lr = 0.001 grs = 1
# Epoch 63 - loss 9.5535  /  val loss 8.0252 lr = 0.001 grs = 1
# Epoch 64 - loss 9.4098  /  val loss 7.8857 lr = 0.001 grs = 1
# Epoch 65 - loss 9.2594  /  val loss 7.782 lr = 0.001 grs = 1
# Epoch 66 - loss 9.1376  /  val loss 7.6684 lr = 0.001 grs = 1
# Epoch 67 - loss 9.0182  /  val loss 7.5743 lr = 0.001 grs = 1
# Epoch 68 - loss 8.9187  /  val loss 7.4971 lr = 0.001 grs = 1
# Epoch 69 - loss 8.8267  /  val loss 7.4135 lr = 0.001 grs = 1
# Epoch 70 - loss 8.7399  /  val loss 7.3391 lr = 0.001 grs = 1
# Epoch 71 - loss 8.6698  /  val loss 7.2865 lr = 0.001 grs = 1
# Epoch 72 - loss 8.6034  /  val loss 7.2494 lr = 0.001 grs = 1
# Epoch 73 - loss 8.5494  /  val loss 7.1997 lr = 0.001 grs = 1
# Epoch 74 - loss 8.4982  /  val loss 7.1677 lr = 0.001 grs = 1
# Epoch 75 - loss 8.456  /  val loss 7.152 lr = 0.001 grs = 1
# Epoch 76 - loss 8.4209  /  val loss 7.1176 lr = 0.001 grs = 1
# Epoch 77 - loss 8.3876  /  val loss 7.091 lr = 0.001 grs = 1
# Epoch 78 - loss 8.361  /  val loss 7.0863 lr = 0.001 grs = 1
# Epoch 79 - loss 8.3385  /  val loss 7.0534 lr = 0.001 grs = 1
# Epoch 80 - loss 8.3129  /  val loss 7.0415 lr = 0.001 grs = 1
# Epoch 81 - loss 8.2908  /  val loss 7.0311 lr = 0.001 grs = 1
# Epoch 82 - loss 8.2739  /  val loss 7.0058 lr = 0.001 grs = 1
# Epoch 83 - loss 8.2554  /  val loss 6.9878 lr = 0.001 grs = 1
# Epoch 84 - loss 8.24  /  val loss 6.9873 lr = 0.001 grs = 1
# Epoch 85 - loss 8.2267  /  val loss 6.9495 lr = 0.001 grs = 1
# Epoch 86 - loss 8.2032  /  val loss 6.9421 lr = 0.001 grs = 1
# Epoch 87 - loss 8.1718  /  val loss 6.9062 lr = 0.001 grs = 1
# Epoch 88 - loss 8.1399  /  val loss 6.8869 lr = 0.001 grs = 1
# Epoch 89 - loss 8.1209  /  val loss 6.8896 lr = 0.001 grs = 1
# Epoch 90 - loss 8.1087  /  val loss 6.8616 lr = 0.001 grs = 1
# Epoch 91 - loss 8.0904  /  val loss 6.8506 lr = 0.001 grs = 1
# Epoch 92 - loss 8.0654  /  val loss 6.8268 lr = 0.001 grs = 1
# Epoch 93 - loss 8.0386  /  val loss 6.8065 lr = 0.001 grs = 1
# Epoch 94 - loss 8.0169  /  val loss 6.8 lr = 0.001 grs = 1
# Epoch 95 - loss 8.0004  /  val loss 6.7773 lr = 0.001 grs = 1
# Epoch 96 - loss 7.9837  /  val loss 6.7687 lr = 0.001 grs = 1
# Epoch 97 - loss 7.9634  /  val loss 6.7358 lr = 0.001 grs = 1
# Epoch 98 - loss 7.9357  /  val loss 6.7217 lr = 0.001 grs = 1
# Epoch 99 - loss 7.9071  /  val loss 6.6964 lr = 0.001 grs = 1
# Epoch 100 - loss 7.881  /  val loss 6.6801 lr = 0.001 grs = 1
# Epoch 101 - loss 7.8569  /  val loss 6.665 lr = 0.001 grs = 1
# Epoch 102 - loss 7.8327  /  val loss 6.6361 lr = 0.001 grs = 1
# Epoch 103 - loss 7.8057  /  val loss 6.6261 lr = 0.001 grs = 1
# Epoch 104 - loss 7.7758  /  val loss 6.5849 lr = 0.001 grs = 1
# Epoch 105 - loss 7.7409  /  val loss 6.5689 lr = 0.001 grs = 1
# Epoch 106 - loss 7.7027  /  val loss 6.5206 lr = 0.001 grs = 1
# Epoch 107 - loss 7.6597  /  val loss 6.4917 lr = 0.001 grs = 1
# Epoch 108 - loss 7.6133  /  val loss 6.4448 lr = 0.001 grs = 1
# Epoch 109 - loss 7.5634  /  val loss 6.4035 lr = 0.001 grs = 1
# Epoch 110 - loss 7.5099  /  val loss 6.356 lr = 0.001 grs = 1
# Epoch 111 - loss 7.4517  /  val loss 6.3017 lr = 0.001 grs = 1
# Epoch 112 - loss 7.388  /  val loss 6.2518 lr = 0.001 grs = 1
# Epoch 113 - loss 7.3189  /  val loss 6.185 lr = 0.001 grs = 1
# Epoch 114 - loss 7.2454  /  val loss 6.1433 lr = 0.001 grs = 1
# Epoch 115 - loss 7.1739  /  val loss 6.0735 lr = 0.001 grs = 1
# Epoch 116 - loss 7.1096  /  val loss 6.0655 lr = 0.001 grs = 1
# Epoch 117 - loss 7.06  /  val loss 5.9914 lr = 0.001 grs = 1
# Epoch 118 - loss 6.9842  /  val loss 5.9246 lr = 0.001 grs = 1
# Epoch 119 - loss 6.9318  /  val loss 6.2564 lr = 0.001 grs = 1
# Epoch 120 - loss 7.1325  /  val loss 6.2338 lr = 0.001 grs = 1
# Epoch 121 - loss 7.2643  /  val loss 5.7518 lr = 0.001 grs = 1
# Epoch 122 - loss 6.601  /  val loss 5.7336 lr = 0.001 grs = 1
# Epoch 123 - loss 6.5532  /  val loss 5.775 lr = 0.001 grs = 1
# Epoch 124 - loss 6.7215  /  val loss 5.4078 lr = 0.001 grs = 1
# Epoch 125 - loss 6.2226  /  val loss 5.6688 lr = 0.001 grs = 1
# Epoch 126 - loss 6.3789  /  val loss 5.4044 lr = 0.001 grs = 1
# Epoch 127 - loss 6.234  /  val loss 5.2693 lr = 0.001 grs = 1
# Epoch 128 - loss 6.0457  /  val loss 5.3665 lr = 0.001 grs = 1
# Epoch 129 - loss 6.0057  /  val loss 5.2239 lr = 0.001 grs = 1
# Epoch 130 - loss 5.8885  /  val loss 5.0959 lr = 0.001 grs = 1
# Epoch 131 - loss 5.7882  /  val loss 4.9869 lr = 0.001 grs = 1
# Epoch 132 - loss 5.6186  /  val loss 5.0434 lr = 0.001 grs = 1
# Epoch 133 - loss 5.6199  /  val loss 4.8448 lr = 0.001 grs = 1
# Epoch 134 - loss 5.4072  /  val loss 4.8723 lr = 0.001 grs = 1
# Epoch 135 - loss 5.4417  /  val loss 4.7176 lr = 0.001 grs = 1
# Epoch 136 - loss 5.2634  /  val loss 4.7825 lr = 0.001 grs = 1
# Epoch 137 - loss 5.2613  /  val loss 4.667 lr = 0.001 grs = 1
# Epoch 138 - loss 5.1267  /  val loss 4.6197 lr = 0.001 grs = 1
# Epoch 139 - loss 5.1246  /  val loss 4.5341 lr = 0.001 grs = 1
# Epoch 140 - loss 4.988  /  val loss 4.61 lr = 0.001 grs = 1
# Epoch 141 - loss 5.002  /  val loss 4.466 lr = 0.001 grs = 1
# Epoch 142 - loss 4.8825  /  val loss 4.4506 lr = 0.001 grs = 1
# Epoch 143 - loss 4.8671  /  val loss 4.4153 lr = 0.001 grs = 1
# Epoch 144 - loss 4.7807  /  val loss 4.4028 lr = 0.001 grs = 1
# Epoch 145 - loss 4.7619  /  val loss 4.3261 lr = 0.001 grs = 1
# Epoch 146 - loss 4.6763  /  val loss 4.3173 lr = 0.001 grs = 1
# Epoch 147 - loss 4.6598  /  val loss 4.2591 lr = 0.001 grs = 1
# Epoch 148 - loss 4.5916  /  val loss 4.2766 lr = 0.001 grs = 1
# Epoch 149 - loss 4.5681  /  val loss 4.204 lr = 0.001 grs = 1
# Epoch 150 - loss 4.5003  /  val loss 4.1787 lr = 0.001 grs = 1
# Epoch 151 - loss 4.482  /  val loss 4.178 lr = 0.001 grs = 1
# Epoch 152 - loss 4.4337  /  val loss 4.1452 lr = 0.001 grs = 1
# Epoch 153 - loss 4.4015  /  val loss 4.1046 lr = 0.001 grs = 1
# Epoch 154 - loss 4.3564  /  val loss 4.0754 lr = 0.001 grs = 1
# Epoch 155 - loss 4.3223  /  val loss 4.0659 lr = 0.001 grs = 1
# Epoch 156 - loss 4.2902  /  val loss 4.0515 lr = 0.001 grs = 1
# Epoch 157 - loss 4.2534  /  val loss 4.0045 lr = 0.001 grs = 1
# Epoch 158 - loss 4.2306  /  val loss 4.0014 lr = 0.001 grs = 1
# Epoch 159 - loss 4.1897  /  val loss 3.9765 lr = 0.001 grs = 1
# Epoch 160 - loss 4.1652  /  val loss 3.9519 lr = 0.001 grs = 1
# Epoch 161 - loss 4.1255  /  val loss 3.9135 lr = 0.001 grs = 1
# Epoch 162 - loss 4.0994  /  val loss 3.919 lr = 0.001 grs = 1
# Epoch 163 - loss 4.0674  /  val loss 3.8764 lr = 0.001 grs = 1
# Epoch 164 - loss 4.0377  /  val loss 3.8847 lr = 0.001 grs = 1
# Epoch 165 - loss 4.0225  /  val loss 3.8404 lr = 0.001 grs = 1
# Epoch 166 - loss 4.0031  /  val loss 3.9292 lr = 0.001 grs = 1
# Epoch 167 - loss 4.0234  /  val loss 3.885 lr = 0.001 grs = 1
# Epoch 168 - loss 4.0669  /  val loss 4.0684 lr = 0.001 grs = 1
# Epoch 169 - loss 4.143  /  val loss 3.9338 lr = 0.001 grs = 1
# Epoch 170 - loss 4.1035  /  val loss 3.8748 lr = 0.001 grs = 1
# Epoch 171 - loss 3.9441  /  val loss 3.7138 lr = 0.001 grs = 1
# Epoch 172 - loss 3.8221  /  val loss 3.7068 lr = 0.001 grs = 1
# Epoch 173 - loss 3.8321  /  val loss 3.8381 lr = 0.001 grs = 1
# Epoch 174 - loss 3.8895  /  val loss 3.7189 lr = 0.001 grs = 1
# Epoch 175 - loss 3.8511  /  val loss 3.6713 lr = 0.001 grs = 1
# Epoch 176 - loss 3.7374  /  val loss 3.6552 lr = 0.001 grs = 1
# Epoch 177 - loss 3.7121  /  val loss 3.6352 lr = 0.001 grs = 1
# Epoch 178 - loss 3.7535  /  val loss 3.7028 lr = 0.001 grs = 1
# Epoch 179 - loss 3.7367  /  val loss 3.5689 lr = 0.001 grs = 1
# Epoch 180 - loss 3.6502  /  val loss 3.5445 lr = 0.001 grs = 1
# Epoch 181 - loss 3.6082  /  val loss 3.6014 lr = 0.001 grs = 1
# Epoch 182 - loss 3.6296  /  val loss 3.5396 lr = 0.001 grs = 1
# Epoch 183 - loss 3.6287  /  val loss 3.5475 lr = 0.001 grs = 1
# Epoch 184 - loss 3.5649  /  val loss 3.4791 lr = 0.001 grs = 1
# Epoch 185 - loss 3.5137  /  val loss 3.4653 lr = 0.001 grs = 1
# Epoch 186 - loss 3.5162  /  val loss 3.514 lr = 0.001 grs = 1
# Epoch 187 - loss 3.5132  /  val loss 3.4293 lr = 0.001 grs = 1
# Epoch 188 - loss 3.4783  /  val loss 3.4259 lr = 0.001 grs = 1
# Epoch 189 - loss 3.4344  /  val loss 3.4065 lr = 0.001 grs = 1
# Epoch 190 - loss 3.4107  /  val loss 3.3824 lr = 0.001 grs = 1
# Epoch 191 - loss 3.4048  /  val loss 3.414 lr = 0.001 grs = 1
# Epoch 192 - loss 3.3887  /  val loss 3.3488 lr = 0.001 grs = 1
# Epoch 193 - loss 3.3566  /  val loss 3.355 lr = 0.001 grs = 1
# Epoch 194 - loss 3.3227  /  val loss 3.326 lr = 0.001 grs = 1
# Epoch 195 - loss 3.2968  /  val loss 3.306 lr = 0.001 grs = 1
# Epoch 196 - loss 3.2753  /  val loss 3.3219 lr = 0.001 grs = 1
# Epoch 197 - loss 3.256  /  val loss 3.2807 lr = 0.001 grs = 1
# Epoch 198 - loss 3.2348  /  val loss 3.3009 lr = 0.001 grs = 1
# Epoch 199 - loss 3.2129  /  val loss 3.2593 lr = 0.001 grs = 1
# Epoch 200 - loss 3.1853  /  val loss 3.2591 lr = 0.001 grs = 1
# Epoch 201 - loss 3.1523  /  val loss 3.2184 lr = 0.001 grs = 1
# Epoch 202 - loss 3.1198  /  val loss 3.2213 lr = 0.001 grs = 1
# Epoch 203 - loss 3.1022  /  val loss 3.236 lr = 0.001 grs = 1
# Epoch 204 - loss 3.1013  /  val loss 3.2408 lr = 0.001 grs = 1
# Epoch 205 - loss 3.126  /  val loss 3.4246 lr = 0.001 grs = 1
# Epoch 206 - loss 3.2281  /  val loss 3.5104 lr = 0.001 grs = 1
# Epoch 207 - loss 3.4344  /  val loss 3.8197 lr = 0.001 grs = 1
# Epoch 208 - loss 3.5605  /  val loss 3.5396 lr = 0.001 grs = 1
# Epoch 209 - loss 3.4368  /  val loss 3.3222 lr = 0.001 grs = 1
# Epoch 210 - loss 3.0842  /  val loss 3.2648 lr = 0.001 grs = 1
# Epoch 211 - loss 3.0544  /  val loss 3.2778 lr = 0.001 grs = 1
# Epoch 212 - loss 3.1363  /  val loss 3.3511 lr = 0.001 grs = 1
# Epoch 213 - loss 3.0943  /  val loss 3.2311 lr = 0.001 grs = 1
# Epoch 214 - loss 3.036  /  val loss 3.1843 lr = 0.001 grs = 1
# Epoch 215 - loss 2.9613  /  val loss 3.172 lr = 0.001 grs = 1
# Epoch 216 - loss 2.9117  /  val loss 3.174 lr = 0.001 grs = 1
# Epoch 217 - loss 2.9734  /  val loss 3.155 lr = 0.001 grs = 1
# Epoch 218 - loss 2.8939  /  val loss 3.0893 lr = 0.001 grs = 1
# Epoch 219 - loss 2.8265  /  val loss 3.1131 lr = 0.001 grs = 1
# Epoch 220 - loss 2.8767  /  val loss 3.0984 lr = 0.001 grs = 1
# Epoch 221 - loss 2.8189  /  val loss 3.0924 lr = 0.001 grs = 1
# Epoch 222 - loss 2.8117  /  val loss 3.0519 lr = 0.001 grs = 1
# Epoch 223 - loss 2.7876  /  val loss 3.0668 lr = 0.001 grs = 1
# Epoch 224 - loss 2.7761  /  val loss 3.0292 lr = 0.001 grs = 1
# Epoch 225 - loss 2.7582  /  val loss 3.03 lr = 0.001 grs = 1
# Epoch 226 - loss 2.7497  /  val loss 3.0302 lr = 0.001 grs = 1
# Epoch 227 - loss 2.7324  /  val loss 2.9757 lr = 0.001 grs = 1
# Epoch 228 - loss 2.7167  /  val loss 3.0065 lr = 0.001 grs = 1
# Epoch 229 - loss 2.71  /  val loss 2.987 lr = 0.001 grs = 1
# Epoch 230 - loss 2.6857  /  val loss 2.9602 lr = 0.001 grs = 1
# Epoch 231 - loss 2.7025  /  val loss 2.9713 lr = 0.001 grs = 1
# Epoch 232 - loss 2.6651  /  val loss 2.9612 lr = 0.001 grs = 1
# Epoch 233 - loss 2.6613  /  val loss 2.9253 lr = 0.001 grs = 1
# Epoch 234 - loss 2.6498  /  val loss 2.9417 lr = 0.001 grs = 1
# Epoch 235 - loss 2.6378  /  val loss 2.9262 lr = 0.001 grs = 1
# Epoch 236 - loss 2.64  /  val loss 2.915 lr = 0.001 grs = 1
# Epoch 237 - loss 2.6167  /  val loss 2.8965 lr = 0.001 grs = 1
# Epoch 238 - loss 2.611  /  val loss 2.8874 lr = 0.001 grs = 1
# Epoch 239 - loss 2.5992  /  val loss 2.898 lr = 0.001 grs = 1
# Epoch 240 - loss 2.5914  /  val loss 2.8599 lr = 0.001 grs = 1
# Epoch 241 - loss 2.5818  /  val loss 2.8766 lr = 0.001 grs = 1
# Epoch 242 - loss 2.5718  /  val loss 2.8578 lr = 0.001 grs = 1
# Epoch 243 - loss 2.5638  /  val loss 2.8519 lr = 0.001 grs = 1
# Epoch 244 - loss 2.5548  /  val loss 2.8549 lr = 0.001 grs = 1
# Epoch 245 - loss 2.5547  /  val loss 2.8492 lr = 0.001 grs = 1
# Epoch 246 - loss 2.5499  /  val loss 2.8571 lr = 0.001 grs = 1
# Epoch 247 - loss 2.5571  /  val loss 2.8855 lr = 0.001 grs = 1
# Epoch 248 - loss 2.5745  /  val loss 2.8918 lr = 0.001 grs = 1
# Epoch 249 - loss 2.605  /  val loss 2.9533 lr = 0.001 grs = 1
# Epoch 250 - loss 2.6377  /  val loss 2.9208 lr = 0.001 grs = 1
# Epoch 251 - loss 2.6249  /  val loss 2.8642 lr = 0.001 grs = 1
# Epoch 252 - loss 2.587  /  val loss 2.8906 lr = 0.001 grs = 1
# Epoch 253 - loss 2.5528  /  val loss 2.8135 lr = 0.001 grs = 1
# Epoch 254 - loss 2.562  /  val loss 2.9057 lr = 0.001 grs = 1
# Epoch 255 - loss 2.5585  /  val loss 2.7674 lr = 0.001 grs = 1
# Epoch 256 - loss 2.4967  /  val loss 2.762 lr = 0.001 grs = 1
# Epoch 257 - loss 2.4583  /  val loss 2.7888 lr = 0.001 grs = 1
# Epoch 258 - loss 2.4752  /  val loss 2.7475 lr = 0.001 grs = 1
# Epoch 259 - loss 2.4766  /  val loss 2.7686 lr = 0.001 grs = 1
# Epoch 260 - loss 2.448  /  val loss 2.7361 lr = 0.001 grs = 1
# Epoch 261 - loss 2.4458  /  val loss 2.7622 lr = 0.001 grs = 1
# Epoch 262 - loss 2.4643  /  val loss 2.7553 lr = 0.001 grs = 1
# Epoch 263 - loss 2.4606  /  val loss 2.7479 lr = 0.001 grs = 1
# Epoch 264 - loss 2.4382  /  val loss 2.7064 lr = 0.001 grs = 1
# Epoch 265 - loss 2.4351  /  val loss 2.777 lr = 0.001 grs = 1
# Epoch 266 - loss 2.4437  /  val loss 2.6939 lr = 0.001 grs = 1
# Epoch 267 - loss 2.4341  /  val loss 2.7346 lr = 0.001 grs = 1
# Epoch 268 - loss 2.4115  /  val loss 2.6868 lr = 0.001 grs = 1
# Epoch 269 - loss 2.4052  /  val loss 2.706 lr = 0.001 grs = 1
# Epoch 270 - loss 2.4102  /  val loss 2.7044 lr = 0.001 grs = 1
# Epoch 271 - loss 2.4091  /  val loss 2.699 lr = 0.001 grs = 1
# Epoch 272 - loss 2.3974  /  val loss 2.6668 lr = 0.001 grs = 1
# Epoch 273 - loss 2.3996  /  val loss 2.7395 lr = 0.001 grs = 1
# Epoch 274 - loss 2.4138  /  val loss 2.6786 lr = 0.001 grs = 1
# Epoch 275 - loss 2.4344  /  val loss 2.7723 lr = 0.001 grs = 1
# Epoch 276 - loss 2.4466  /  val loss 2.7175 lr = 0.001 grs = 1
# Epoch 277 - loss 2.4634  /  val loss 2.7836 lr = 0.001 grs = 1
# Epoch 278 - loss 2.4708  /  val loss 2.7474 lr = 0.001 grs = 1
# Epoch 279 - loss 2.4822  /  val loss 2.7394 lr = 0.001 grs = 1
# Epoch 280 - loss 2.4348  /  val loss 2.6399 lr = 0.001 grs = 1
# Epoch 281 - loss 2.3746  /  val loss 2.6205 lr = 0.001 grs = 1
# Epoch 282 - loss 2.3162  /  val loss 2.5559 lr = 0.001 grs = 1
# Epoch 283 - loss 2.2947  /  val loss 2.5815 lr = 0.001 grs = 1
# Epoch 284 - loss 2.2951  /  val loss 2.5823 lr = 0.001 grs = 1
# Epoch 285 - loss 2.2981  /  val loss 2.5557 lr = 0.001 grs = 1
# Epoch 286 - loss 2.3065  /  val loss 2.6294 lr = 0.001 grs = 1
# Epoch 287 - loss 2.315  /  val loss 2.5495 lr = 0.001 grs = 1
# Epoch 288 - loss 2.3139  /  val loss 2.5983 lr = 0.001 grs = 1
# Epoch 289 - loss 2.2895  /  val loss 2.5125 lr = 0.001 grs = 1
# Epoch 290 - loss 2.2562  /  val loss 2.5108 lr = 0.001 grs = 1
# Epoch 291 - loss 2.2361  /  val loss 2.5174 lr = 0.001 grs = 1
# Epoch 292 - loss 2.2344  /  val loss 2.4859 lr = 0.001 grs = 1
# Epoch 293 - loss 2.238  /  val loss 2.5242 lr = 0.001 grs = 1
# Epoch 294 - loss 2.2362  /  val loss 2.4756 lr = 0.001 grs = 1
# Epoch 295 - loss 2.2306  /  val loss 2.5037 lr = 0.001 grs = 1
# Epoch 296 - loss 2.2279  /  val loss 2.4886 lr = 0.001 grs = 1
# Epoch 297 - loss 2.2322  /  val loss 2.5006 lr = 0.001 grs = 1
# Epoch 298 - loss 2.236  /  val loss 2.5003 lr = 0.001 grs = 1
# Epoch 299 - loss 2.2368  /  val loss 2.4938 lr = 0.001 grs = 1
# Epoch 300 - loss 2.2304  /  val loss 2.4771 lr = 0.001 grs = 1
# Epoch 301 - loss 2.2242  /  val loss 2.4928 lr = 0.001 grs = 1
# Epoch 302 - loss 2.2172  /  val loss 2.4501 lr = 0.001 grs = 1
# Epoch 303 - loss 2.2183  /  val loss 2.5124 lr = 0.001 grs = 1
# Epoch 304 - loss 2.2211  /  val loss 2.4451 lr = 0.001 grs = 1
# Epoch 305 - loss 2.2267  /  val loss 2.5218 lr = 0.001 grs = 1
# Epoch 306 - loss 2.2259  /  val loss 2.4441 lr = 0.001 grs = 1
# Epoch 307 - loss 2.2243  /  val loss 2.5002 lr = 0.001 grs = 1
# Epoch 308 - loss 2.2142  /  val loss 2.4444 lr = 0.001 grs = 1
# Epoch 309 - loss 2.211  /  val loss 2.4738 lr = 0.001 grs = 1
# Epoch 310 - loss 2.2064  /  val loss 2.4605 lr = 0.001 grs = 1
# Epoch 311 - loss 2.2112  /  val loss 2.4582 lr = 0.001 grs = 1
# Epoch 312 - loss 2.2071  /  val loss 2.4486 lr = 0.001 grs = 1
# Epoch 313 - loss 2.1958  /  val loss 2.414 lr = 0.001 grs = 1
# Epoch 314 - loss 2.1614  /  val loss 2.3678 lr = 0.001 grs = 1
# Epoch 315 - loss 2.127  /  val loss 2.377 lr = 0.001 grs = 1
# Epoch 316 - loss 2.1067  /  val loss 2.3361 lr = 0.001 grs = 1
# Epoch 317 - loss 2.1062  /  val loss 2.3861 lr = 0.001 grs = 1
# Epoch 318 - loss 2.1095  /  val loss 2.3368 lr = 0.001 grs = 1
# Epoch 319 - loss 2.1019  /  val loss 2.3475 lr = 0.001 grs = 1
# Epoch 320 - loss 2.084  /  val loss 2.3254 lr = 0.001 grs = 1
# Epoch 321 - loss 2.0699  /  val loss 2.3128 lr = 0.001 grs = 1
# Epoch 322 - loss 2.0683  /  val loss 2.3501 lr = 0.001 grs = 1
# Epoch 323 - loss 2.0746  /  val loss 2.3095 lr = 0.001 grs = 1
# Epoch 324 - loss 2.0797  /  val loss 2.3618 lr = 0.001 grs = 1
# Epoch 325 - loss 2.0783  /  val loss 2.2994 lr = 0.001 grs = 1
# Epoch 326 - loss 2.0737  /  val loss 2.3562 lr = 0.001 grs = 1
# Epoch 327 - loss 2.0732  /  val loss 2.3197 lr = 0.001 grs = 1
# Epoch 328 - loss 2.0881  /  val loss 2.403 lr = 0.001 grs = 1
# Epoch 329 - loss 2.1232  /  val loss 2.4276 lr = 0.001 grs = 1
# Epoch 330 - loss 2.1973  /  val loss 2.5823 lr = 0.001 grs = 1
# Epoch 331 - loss 2.2962  /  val loss 2.6803 lr = 0.001 grs = 1
# Epoch 332 - loss 2.4702  /  val loss 2.8513 lr = 0.001 grs = 1
# Epoch 333 - loss 2.5415  /  val loss 2.7854 lr = 0.001 grs = 1
# Epoch 334 - loss 2.6081  /  val loss 2.7105 lr = 0.001 grs = 1
# Epoch 335 - loss 2.3675  /  val loss 2.3622 lr = 0.001 grs = 1
# Epoch 336 - loss 2.1834  /  val loss 2.3865 lr = 0.001 grs = 1
# Epoch 337 - loss 2.0831  /  val loss 2.3818 lr = 0.001 grs = 1
# Epoch 338 - loss 2.1072  /  val loss 2.3883 lr = 0.001 grs = 1
# Epoch 339 - loss 2.2037  /  val loss 2.5413 lr = 0.001 grs = 1
# Epoch 340 - loss 2.1979  /  val loss 2.2935 lr = 0.001 grs = 1
# Epoch 341 - loss 2.0932  /  val loss 2.2639 lr = 0.001 grs = 1
# Epoch 342 - loss 2.013  /  val loss 2.4014 lr = 0.001 grs = 1
# Epoch 343 - loss 2.089  /  val loss 2.3333 lr = 0.001 grs = 1
# Epoch 344 - loss 2.1393  /  val loss 2.3311 lr = 0.001 grs = 1
# Epoch 345 - loss 2.0458  /  val loss 2.2907 lr = 0.001 grs = 1
# Epoch 346 - loss 2.008  /  val loss 2.2574 lr = 0.001 grs = 1
# Epoch 347 - loss 2.0384  /  val loss 2.3231 lr = 0.001 grs = 1
# Epoch 348 - loss 2.0331  /  val loss 2.2948 lr = 0.001 grs = 1
# Epoch 349 - loss 2.0263  /  val loss 2.2436 lr = 0.001 grs = 1
# Epoch 350 - loss 2.0108  /  val loss 2.2672 lr = 0.001 grs = 1
# Epoch 351 - loss 1.9866  /  val loss 2.2568 lr = 0.001 grs = 1
# Epoch 352 - loss 1.9932  /  val loss 2.2497 lr = 0.001 grs = 1
# Epoch 353 - loss 1.9998  /  val loss 2.2603 lr = 0.001 grs = 1
# Epoch 354 - loss 1.9796  /  val loss 2.2414 lr = 0.001 grs = 1
# Epoch 355 - loss 1.9705  /  val loss 2.2295 lr = 0.001 grs = 1
# Epoch 356 - loss 1.9757  /  val loss 2.242 lr = 0.001 grs = 1
# Epoch 357 - loss 1.9673  /  val loss 2.2318 lr = 0.001 grs = 1
# Epoch 358 - loss 1.9558  /  val loss 2.2084 lr = 0.001 grs = 1
# Epoch 359 - loss 1.9567  /  val loss 2.2354 lr = 0.001 grs = 1
# Epoch 360 - loss 1.9535  /  val loss 2.2239 lr = 0.001 grs = 1
# Epoch 361 - loss 1.9483  /  val loss 2.1997 lr = 0.001 grs = 1
# Epoch 362 - loss 1.9498  /  val loss 2.2352 lr = 0.001 grs = 1
# Epoch 363 - loss 1.9426  /  val loss 2.1971 lr = 0.001 grs = 1
# Epoch 364 - loss 1.9304  /  val loss 2.1957 lr = 0.001 grs = 1
# Epoch 365 - loss 1.9318  /  val loss 2.2313 lr = 0.001 grs = 1
# Epoch 366 - loss 1.9359  /  val loss 2.187 lr = 0.001 grs = 1
# Epoch 367 - loss 1.9283  /  val loss 2.2012 lr = 0.001 grs = 1
# Epoch 368 - loss 1.9218  /  val loss 2.209 lr = 0.001 grs = 1
# Epoch 369 - loss 1.9232  /  val loss 2.189 lr = 0.001 grs = 1
# Epoch 370 - loss 1.921  /  val loss 2.2027 lr = 0.001 grs = 1
# Epoch 371 - loss 1.9148  /  val loss 2.1951 lr = 0.001 grs = 1
# Epoch 372 - loss 1.9137  /  val loss 2.1878 lr = 0.001 grs = 1
# Epoch 373 - loss 1.9133  /  val loss 2.1955 lr = 0.001 grs = 1
# Epoch 374 - loss 1.9075  /  val loss 2.1836 lr = 0.001 grs = 1
# Epoch 375 - loss 1.9022  /  val loss 2.1844 lr = 0.001 grs = 1
# Epoch 376 - loss 1.9022  /  val loss 2.1895 lr = 0.001 grs = 1
# Epoch 377 - loss 1.9022  /  val loss 2.1838 lr = 0.001 grs = 1
# Epoch 378 - loss 1.8986  /  val loss 2.1751 lr = 0.001 grs = 1
# Epoch 379 - loss 1.8954  /  val loss 2.1936 lr = 0.001 grs = 1
# Epoch 380 - loss 1.8954  /  val loss 2.1748 lr = 0.001 grs = 1
# Epoch 381 - loss 1.8964  /  val loss 2.1972 lr = 0.001 grs = 1
# Epoch 382 - loss 1.8987  /  val loss 2.1913 lr = 0.001 grs = 1
# Epoch 383 - loss 1.9065  /  val loss 2.2182 lr = 0.001 grs = 1
# Epoch 384 - loss 1.9276  /  val loss 2.2539 lr = 0.001 grs = 1
# Epoch 385 - loss 1.9671  /  val loss 2.3299 lr = 0.001 grs = 1
# Epoch 386 - loss 2.0361  /  val loss 2.394 lr = 0.001 grs = 1
# Epoch 387 - loss 2.1176  /  val loss 2.505 lr = 0.001 grs = 1
# Epoch 388 - loss 2.2075  /  val loss 2.4345 lr = 0.001 grs = 1
# Epoch 389 - loss 2.1522  /  val loss 2.3287 lr = 0.001 grs = 1
# Epoch 390 - loss 2.0656  /  val loss 2.3201 lr = 0.001 grs = 1
# Epoch 391 - loss 1.9891  /  val loss 2.2455 lr = 0.001 grs = 1
# Epoch 392 - loss 2.0192  /  val loss 2.3255 lr = 0.001 grs = 1
# Epoch 393 - loss 1.9941  /  val loss 2.1762 lr = 0.001 grs = 1
# Epoch 394 - loss 1.8944  /  val loss 2.1571 lr = 0.001 grs = 1
# Epoch 395 - loss 1.8952  /  val loss 2.2935 lr = 0.001 grs = 1
# Epoch 396 - loss 1.9511  /  val loss 2.19 lr = 0.001 grs = 1
# Epoch 397 - loss 1.9278  /  val loss 2.2021 lr = 0.001 grs = 1
# Epoch 398 - loss 1.9039  /  val loss 2.2393 lr = 0.001 grs = 1
# Epoch 399 - loss 1.9291  /  val loss 2.1809 lr = 0.001 grs = 1
# Epoch 400 - loss 1.899  /  val loss 2.145 lr = 0.001 grs = 1
# Epoch 401 - loss 1.8589  /  val loss 2.1983 lr = 0.001 grs = 1
# Epoch 402 - loss 1.8794  /  val loss 2.1669 lr = 0.001 grs = 1
# Epoch 403 - loss 1.888  /  val loss 2.1582 lr = 0.001 grs = 1
# Epoch 404 - loss 1.8684  /  val loss 2.2071 lr = 0.001 grs = 1
# Epoch 405 - loss 1.8753  /  val loss 2.1466 lr = 0.001 grs = 1
# Epoch 406 - loss 1.8799  /  val loss 2.1816 lr = 0.001 grs = 1
# Epoch 407 - loss 1.8552  /  val loss 2.1584 lr = 0.001 grs = 1
# Epoch 408 - loss 1.8462  /  val loss 2.1428 lr = 0.001 grs = 1
# Epoch 409 - loss 1.8535  /  val loss 2.1793 lr = 0.001 grs = 1
# Epoch 410 - loss 1.8473  /  val loss 2.1433 lr = 0.001 grs = 1
# Epoch 411 - loss 1.8409  /  val loss 2.1595 lr = 0.001 grs = 1
# Epoch 412 - loss 1.8484  /  val loss 2.1706 lr = 0.001 grs = 1
# Epoch 413 - loss 1.8495  /  val loss 2.1525 lr = 0.001 grs = 1
# Epoch 414 - loss 1.8381  /  val loss 2.1453 lr = 0.001 grs = 1
# Epoch 415 - loss 1.8372  /  val loss 2.1727 lr = 0.001 grs = 1
# Epoch 416 - loss 1.841  /  val loss 2.1413 lr = 0.001 grs = 1
# Epoch 417 - loss 1.8329  /  val loss 2.1474 lr = 0.001 grs = 1
# Epoch 418 - loss 1.8229  /  val loss 2.1478 lr = 0.001 grs = 1
# Epoch 419 - loss 1.8232  /  val loss 2.1423 lr = 0.001 grs = 1
# Epoch 420 - loss 1.8234  /  val loss 2.1407 lr = 0.001 grs = 1
# Epoch 421 - loss 1.8172  /  val loss 2.1458 lr = 0.001 grs = 1
# Epoch 422 - loss 1.8123  /  val loss 2.1248 lr = 0.001 grs = 1
# Epoch 423 - loss 1.8127  /  val loss 2.1531 lr = 0.001 grs = 1
# Epoch 424 - loss 1.8114  /  val loss 2.1261 lr = 0.001 grs = 1
# Epoch 425 - loss 1.8065  /  val loss 2.1354 lr = 0.001 grs = 1
# Epoch 426 - loss 1.8038  /  val loss 2.1409 lr = 0.001 grs = 1
# Epoch 427 - loss 1.8054  /  val loss 2.134 lr = 0.001 grs = 1
# Epoch 428 - loss 1.8077  /  val loss 2.148 lr = 0.001 grs = 1
# Epoch 429 - loss 1.8112  /  val loss 2.1596 lr = 0.001 grs = 1
# Epoch 430 - loss 1.8216  /  val loss 2.1751 lr = 0.001 grs = 1
# Epoch 431 - loss 1.8507  /  val loss 2.2637 lr = 0.001 grs = 1
# Epoch 432 - loss 1.9076  /  val loss 2.3421 lr = 0.001 grs = 1
# Epoch 433 - loss 2.0338  /  val loss 2.5977 lr = 0.001 grs = 1
# Epoch 434 - loss 2.2216  /  val loss 2.8781 lr = 0.001 grs = 1
# Epoch 435 - loss 2.5957  /  val loss 3.0827 lr = 0.001 grs = 1
# Epoch 436 - loss 2.6843  /  val loss 3.0729 lr = 0.001 grs = 1
# Epoch 437 - loss 2.8236  /  val loss 2.7145 lr = 0.001 grs = 1
# Epoch 438 - loss 2.2834  /  val loss 2.3185 lr = 0.001 grs = 1
# Epoch 439 - loss 2.0666  /  val loss 2.3396 lr = 0.001 grs = 1
# Epoch 440 - loss 1.979  /  val loss 2.3945 lr = 0.001 grs = 1
# Epoch 441 - loss 2.0183  /  val loss 2.418 lr = 0.001 grs = 1
# Epoch 442 - loss 2.1829  /  val loss 2.3684 lr = 0.001 grs = 1
# Epoch 443 - loss 1.9656  /  val loss 2.1825 lr = 0.001 grs = 1
# Epoch 444 - loss 1.8368  /  val loss 2.2408 lr = 0.001 grs = 1
# Epoch 445 - loss 1.9743  /  val loss 2.3237 lr = 0.001 grs = 1
# Epoch 446 - loss 1.9425  /  val loss 2.2178 lr = 0.001 grs = 1
# Epoch 447 - loss 1.8662  /  val loss 2.146 lr = 0.001 grs = 1
# Epoch 448 - loss 1.8495  /  val loss 2.2193 lr = 0.001 grs = 1
# Epoch 449 - loss 1.8658  /  val loss 2.2242 lr = 0.001 grs = 1
# Epoch 450 - loss 1.8615  /  val loss 2.1716 lr = 0.001 grs = 1
# Epoch 451 - loss 1.8506  /  val loss 2.1566 lr = 0.001 grs = 1
# Epoch 452 - loss 1.8085  /  val loss 2.1689 lr = 0.001 grs = 1
# Epoch 453 - loss 1.8062  /  val loss 2.1895 lr = 0.001 grs = 1
# Epoch 454 - loss 1.8512  /  val loss 2.1266 lr = 0.001 grs = 1
# Epoch 455 - loss 1.7853  /  val loss 2.1519 lr = 0.001 grs = 1
# Epoch 456 - loss 1.787  /  val loss 2.1501 lr = 0.001 grs = 1
# Epoch 457 - loss 1.7989  /  val loss 2.1232 lr = 0.001 grs = 1
# Epoch 458 - loss 1.7758  /  val loss 2.1547 lr = 0.001 grs = 1
# Epoch 459 - loss 1.7868  /  val loss 2.1025 lr = 0.001 grs = 1
# Epoch 460 - loss 1.7506  /  val loss 2.1171 lr = 0.001 grs = 1
# Epoch 461 - loss 1.7637  /  val loss 2.1452 lr = 0.001 grs = 1
# Epoch 462 - loss 1.7688  /  val loss 2.1029 lr = 0.001 grs = 1
# Epoch 463 - loss 1.7461  /  val loss 2.1058 lr = 0.001 grs = 1
# Epoch 464 - loss 1.749  /  val loss 2.116 lr = 0.001 grs = 1
# Epoch 465 - loss 1.737  /  val loss 2.1041 lr = 0.001 grs = 1
# Epoch 466 - loss 1.7421  /  val loss 2.1029 lr = 0.001 grs = 1
# Epoch 467 - loss 1.7341  /  val loss 2.1123 lr = 0.001 grs = 1
# Epoch 468 - loss 1.7295  /  val loss 2.0912 lr = 0.001 grs = 1
# Epoch 469 - loss 1.7267  /  val loss 2.0885 lr = 0.001 grs = 1
# Epoch 470 - loss 1.713  /  val loss 2.1062 lr = 0.001 grs = 1
# Epoch 471 - loss 1.7209  /  val loss 2.0856 lr = 0.001 grs = 1
# Epoch 472 - loss 1.7143  /  val loss 2.0928 lr = 0.001 grs = 1
# Epoch 473 - loss 1.7081  /  val loss 2.0972 lr = 0.001 grs = 1
# Epoch 474 - loss 1.7088  /  val loss 2.0797 lr = 0.001 grs = 1
# Epoch 475 - loss 1.6984  /  val loss 2.0861 lr = 0.001 grs = 1
# Epoch 476 - loss 1.6968  /  val loss 2.0871 lr = 0.001 grs = 1
# Epoch 477 - loss 1.6928  /  val loss 2.0786 lr = 0.001 grs = 1
# Epoch 478 - loss 1.6897  /  val loss 2.085 lr = 0.001 grs = 1
# Epoch 479 - loss 1.6908  /  val loss 2.0829 lr = 0.001 grs = 1
# Epoch 480 - loss 1.6838  /  val loss 2.0704 lr = 0.001 grs = 1
# Epoch 481 - loss 1.6818  /  val loss 2.0835 lr = 0.001 grs = 1
# Epoch 482 - loss 1.6803  /  val loss 2.0658 lr = 0.001 grs = 1
# Epoch 483 - loss 1.6746  /  val loss 2.0751 lr = 0.001 grs = 1
# Epoch 484 - loss 1.6719  /  val loss 2.0671 lr = 0.001 grs = 1
# Epoch 485 - loss 1.6683  /  val loss 2.0627 lr = 0.001 grs = 1
# Epoch 486 - loss 1.6646  /  val loss 2.067 lr = 0.001 grs = 1
# Epoch 487 - loss 1.6619  /  val loss 2.0639 lr = 0.001 grs = 1
# Epoch 488 - loss 1.6585  /  val loss 2.0564 lr = 0.001 grs = 1
# Epoch 489 - loss 1.6565  /  val loss 2.0717 lr = 0.001 grs = 1
# Epoch 490 - loss 1.6563  /  val loss 2.0528 lr = 0.001 grs = 1
# Epoch 491 - loss 1.6576  /  val loss 2.0829 lr = 0.001 grs = 1
# Epoch 492 - loss 1.6638  /  val loss 2.0747 lr = 0.001 grs = 1
# Epoch 493 - loss 1.6821  /  val loss 2.1474 lr = 0.001 grs = 1
# Epoch 494 - loss 1.7218  /  val loss 2.1745 lr = 0.001 grs = 1
# Epoch 495 - loss 1.7948  /  val loss 2.3274 lr = 0.001 grs = 1
# Epoch 496 - loss 1.8997  /  val loss 2.3407 lr = 0.001 grs = 1
# Epoch 497 - loss 1.9623  /  val loss 2.3543 lr = 0.001 grs = 1
# Epoch 498 - loss 1.9653  /  val loss 2.2621 lr = 0.001 grs = 1
# Epoch 499 - loss 1.8343  /  val loss 2.1236 lr = 0.001 grs = 1
# !!!!!!!!!!!!!!!cahnge lr to` 0.0005
# Epoch 500 - loss 1.7906  /  val loss 2.2074 lr = 0.0005 grs = 1
# Epoch 501 - loss 1.7538  /  val loss 2.0589 lr = 0.0005 grs = 1
# Epoch 502 - loss 1.6411  /  val loss 2.0691 lr = 0.0005 grs = 1
# Epoch 503 - loss 1.7134  /  val loss 2.0254 lr = 0.0005 grs = 1
# Epoch 504 - loss 1.6542  /  val loss 2.1044 lr = 0.0005 grs = 1
# Epoch 505 - loss 1.6707  /  val loss 2.1072 lr = 0.0005 grs = 1
# Epoch 506 - loss 1.666  /  val loss 2.0313 lr = 0.0005 grs = 1
# Epoch 507 - loss 1.6398  /  val loss 2.0389 lr = 0.0005 grs = 1
# Epoch 508 - loss 1.6665  /  val loss 2.0353 lr = 0.0005 grs = 1
# Epoch 509 - loss 1.6256  /  val loss 2.0954 lr = 0.0005 grs = 1
# Epoch 510 - loss 1.6552  /  val loss 2.0427 lr = 0.0005 grs = 1
# Epoch 511 - loss 1.6236  /  val loss 2.0251 lr = 0.0005 grs = 1
# Epoch 512 - loss 1.6382  /  val loss 2.021 lr = 0.0005 grs = 1
# Epoch 513 - loss 1.625  /  val loss 2.0504 lr = 0.0005 grs = 1
# Epoch 514 - loss 1.6225  /  val loss 2.0569 lr = 0.0005 grs = 1
# Epoch 515 - loss 1.625  /  val loss 2.0165 lr = 0.0005 grs = 1
# Epoch 516 - loss 1.6113  /  val loss 2.0165 lr = 0.0005 grs = 1
# Epoch 517 - loss 1.6218  /  val loss 2.0215 lr = 0.0005 grs = 1
# Epoch 518 - loss 1.6048  /  val loss 2.051 lr = 0.0005 grs = 1
# Epoch 519 - loss 1.6161  /  val loss 2.0226 lr = 0.0005 grs = 1
# Epoch 520 - loss 1.6015  /  val loss 2.0113 lr = 0.0005 grs = 1
# Epoch 521 - loss 1.6091  /  val loss 2.0107 lr = 0.0005 grs = 1
# Epoch 522 - loss 1.5999  /  val loss 2.0338 lr = 0.0005 grs = 1
# Epoch 523 - loss 1.6019  /  val loss 2.0295 lr = 0.0005 grs = 1
# Epoch 524 - loss 1.5984  /  val loss 2.0083 lr = 0.0005 grs = 1
# Epoch 525 - loss 1.5955  /  val loss 2.0067 lr = 0.0005 grs = 1
# Epoch 526 - loss 1.5964  /  val loss 2.0179 lr = 0.0005 grs = 1
# Epoch 527 - loss 1.5903  /  val loss 2.0292 lr = 0.0005 grs = 1
# Epoch 528 - loss 1.5936  /  val loss 2.0094 lr = 0.0005 grs = 1
# Epoch 529 - loss 1.5864  /  val loss 2.0045 lr = 0.0005 grs = 1
# Epoch 530 - loss 1.5901  /  val loss 2.0088 lr = 0.0005 grs = 1
# Epoch 531 - loss 1.5834  /  val loss 2.0232 lr = 0.0005 grs = 1
# Epoch 532 - loss 1.5864  /  val loss 2.011 lr = 0.0005 grs = 1
# Epoch 533 - loss 1.5809  /  val loss 2.0027 lr = 0.0005 grs = 1
# Epoch 534 - loss 1.5827  /  val loss 2.0037 lr = 0.0005 grs = 1
# Epoch 535 - loss 1.5785  /  val loss 2.0151 lr = 0.0005 grs = 1
# Epoch 536 - loss 1.5791  /  val loss 2.0094 lr = 0.0005 grs = 1
# Epoch 537 - loss 1.5761  /  val loss 1.9996 lr = 0.0005 grs = 1
# Epoch 538 - loss 1.5757  /  val loss 1.9993 lr = 0.0005 grs = 1
# Epoch 539 - loss 1.5736  /  val loss 2.0077 lr = 0.0005 grs = 1
# Epoch 540 - loss 1.5726  /  val loss 2.0063 lr = 0.0005 grs = 1
# Epoch 541 - loss 1.5712  /  val loss 1.9972 lr = 0.0005 grs = 1
# Epoch 542 - loss 1.5696  /  val loss 1.9963 lr = 0.0005 grs = 1
# Epoch 543 - loss 1.5686  /  val loss 2.0025 lr = 0.0005 grs = 1
# Epoch 544 - loss 1.5669  /  val loss 2.0036 lr = 0.0005 grs = 1
# Epoch 545 - loss 1.5661  /  val loss 1.9958 lr = 0.0005 grs = 1
# Epoch 546 - loss 1.5642  /  val loss 1.9942 lr = 0.0005 grs = 1
# Epoch 547 - loss 1.5635  /  val loss 1.9989 lr = 0.0005 grs = 1
# Epoch 548 - loss 1.5616  /  val loss 2.0009 lr = 0.0005 grs = 1
# Epoch 549 - loss 1.561  /  val loss 1.9948 lr = 0.0005 grs = 1
# Epoch 550 - loss 1.5592  /  val loss 1.9926 lr = 0.0005 grs = 1
# Epoch 551 - loss 1.5585  /  val loss 1.9957 lr = 0.0005 grs = 1
# Epoch 552 - loss 1.5567  /  val loss 1.9979 lr = 0.0005 grs = 1
# Epoch 553 - loss 1.556  /  val loss 1.9933 lr = 0.0005 grs = 1
# Epoch 554 - loss 1.5543  /  val loss 1.9909 lr = 0.0005 grs = 1
# Epoch 555 - loss 1.5536  /  val loss 1.9927 lr = 0.0005 grs = 1
# Epoch 556 - loss 1.5519  /  val loss 1.9947 lr = 0.0005 grs = 1
# Epoch 557 - loss 1.5511  /  val loss 1.9916 lr = 0.0005 grs = 1
# Epoch 558 - loss 1.5496  /  val loss 1.9893 lr = 0.0005 grs = 1
# Epoch 559 - loss 1.5487  /  val loss 1.9902 lr = 0.0005 grs = 1
# Epoch 560 - loss 1.5473  /  val loss 1.9918 lr = 0.0005 grs = 1
# Epoch 561 - loss 1.5463  /  val loss 1.9895 lr = 0.0005 grs = 1
# Epoch 562 - loss 1.545  /  val loss 1.9874 lr = 0.0005 grs = 1
# Epoch 563 - loss 1.544  /  val loss 1.9878 lr = 0.0005 grs = 1
# Epoch 564 - loss 1.5427  /  val loss 1.9888 lr = 0.0005 grs = 1
# Epoch 565 - loss 1.5417  /  val loss 1.9869 lr = 0.0005 grs = 1
# Epoch 566 - loss 1.5404  /  val loss 1.9849 lr = 0.0005 grs = 1
# Epoch 567 - loss 1.5394  /  val loss 1.9853 lr = 0.0005 grs = 1
# Epoch 568 - loss 1.5382  /  val loss 1.986 lr = 0.0005 grs = 1
# Epoch 569 - loss 1.5371  /  val loss 1.9842 lr = 0.0005 grs = 1
# Epoch 570 - loss 1.536  /  val loss 1.9824 lr = 0.0005 grs = 1
# Epoch 571 - loss 1.5349  /  val loss 1.9828 lr = 0.0005 grs = 1
# Epoch 572 - loss 1.5338  /  val loss 1.9832 lr = 0.0005 grs = 1
# Epoch 573 - loss 1.5327  /  val loss 1.9813 lr = 0.0005 grs = 1
# Epoch 574 - loss 1.5316  /  val loss 1.9798 lr = 0.0005 grs = 1
# Epoch 575 - loss 1.5305  /  val loss 1.9803 lr = 0.0005 grs = 1
# Epoch 576 - loss 1.5294  /  val loss 1.9804 lr = 0.0005 grs = 1
# Epoch 577 - loss 1.5283  /  val loss 1.9785 lr = 0.0005 grs = 1
# Epoch 578 - loss 1.5272  /  val loss 1.9774 lr = 0.0005 grs = 1
# Epoch 579 - loss 1.5262  /  val loss 1.9779 lr = 0.0005 grs = 1
# Epoch 580 - loss 1.5251  /  val loss 1.9776 lr = 0.0005 grs = 1
# Epoch 581 - loss 1.524  /  val loss 1.9759 lr = 0.0005 grs = 1
# Epoch 582 - loss 1.5229  /  val loss 1.9753 lr = 0.0005 grs = 1
# Epoch 583 - loss 1.5219  /  val loss 1.9757 lr = 0.0005 grs = 1
# Epoch 584 - loss 1.5208  /  val loss 1.975 lr = 0.0005 grs = 1
# Epoch 585 - loss 1.5198  /  val loss 1.9736 lr = 0.0005 grs = 1
# Epoch 586 - loss 1.5187  /  val loss 1.9735 lr = 0.0005 grs = 1
# Epoch 587 - loss 1.5177  /  val loss 1.9735 lr = 0.0005 grs = 1
# Epoch 588 - loss 1.5166  /  val loss 1.9724 lr = 0.0005 grs = 1
# Epoch 589 - loss 1.5156  /  val loss 1.9714 lr = 0.0005 grs = 1
# Epoch 590 - loss 1.5146  /  val loss 1.9714 lr = 0.0005 grs = 1
# Epoch 591 - loss 1.5135  /  val loss 1.9709 lr = 0.0005 grs = 1
# Epoch 592 - loss 1.5125  /  val loss 1.9698 lr = 0.0005 grs = 1
# Epoch 593 - loss 1.5115  /  val loss 1.9693 lr = 0.0005 grs = 1
# Epoch 594 - loss 1.5105  /  val loss 1.9692 lr = 0.0005 grs = 1
# Epoch 595 - loss 1.5095  /  val loss 1.9684 lr = 0.0005 grs = 1
# Epoch 596 - loss 1.5085  /  val loss 1.9677 lr = 0.0005 grs = 1
# Epoch 597 - loss 1.5075  /  val loss 1.9674 lr = 0.0005 grs = 1
# Epoch 598 - loss 1.5064  /  val loss 1.967 lr = 0.0005 grs = 1
# Epoch 599 - loss 1.5055  /  val loss 1.9662 lr = 0.0005 grs = 1
# Epoch 600 - loss 1.5045  /  val loss 1.9658 lr = 0.0005 grs = 1
# Epoch 601 - loss 1.5035  /  val loss 1.9655 lr = 0.0005 grs = 1
# Epoch 602 - loss 1.5025  /  val loss 1.9648 lr = 0.0005 grs = 1
# Epoch 603 - loss 1.5015  /  val loss 1.9643 lr = 0.0005 grs = 1
# Epoch 604 - loss 1.5005  /  val loss 1.9639 lr = 0.0005 grs = 1
# Epoch 605 - loss 1.4996  /  val loss 1.9633 lr = 0.0005 grs = 1
# Epoch 606 - loss 1.4986  /  val loss 1.9627 lr = 0.0005 grs = 1
# Epoch 607 - loss 1.4976  /  val loss 1.9623 lr = 0.0005 grs = 1
# Epoch 608 - loss 1.4966  /  val loss 1.9618 lr = 0.0005 grs = 1
# Epoch 609 - loss 1.4957  /  val loss 1.9612 lr = 0.0005 grs = 1
# Epoch 610 - loss 1.4947  /  val loss 1.9608 lr = 0.0005 grs = 1
# Epoch 611 - loss 1.4938  /  val loss 1.9603 lr = 0.0005 grs = 1
# Epoch 612 - loss 1.4928  /  val loss 1.9598 lr = 0.0005 grs = 1
# Epoch 613 - loss 1.4919  /  val loss 1.9594 lr = 0.0005 grs = 1
# Epoch 614 - loss 1.4909  /  val loss 1.959 lr = 0.0005 grs = 1
# Epoch 615 - loss 1.49  /  val loss 1.9585 lr = 0.0005 grs = 1
# Epoch 616 - loss 1.489  /  val loss 1.9581 lr = 0.0005 grs = 1
# Epoch 617 - loss 1.4881  /  val loss 1.9578 lr = 0.0005 grs = 1
# Epoch 618 - loss 1.4871  /  val loss 1.9573 lr = 0.0005 grs = 1
# Epoch 619 - loss 1.4862  /  val loss 1.9569 lr = 0.0005 grs = 1
# Epoch 620 - loss 1.4853  /  val loss 1.9565 lr = 0.0005 grs = 1
# Epoch 621 - loss 1.4843  /  val loss 1.956 lr = 0.0005 grs = 1
# Epoch 622 - loss 1.4834  /  val loss 1.9557 lr = 0.0005 grs = 1
# Epoch 623 - loss 1.4825  /  val loss 1.9554 lr = 0.0005 grs = 1
# Epoch 624 - loss 1.4815  /  val loss 1.955 lr = 0.0005 grs = 1
# Epoch 625 - loss 1.4806  /  val loss 1.9546 lr = 0.0005 grs = 1
# Epoch 626 - loss 1.4797  /  val loss 1.9543 lr = 0.0005 grs = 1
# Epoch 627 - loss 1.4787  /  val loss 1.954 lr = 0.0005 grs = 1
# Epoch 628 - loss 1.4778  /  val loss 1.9535 lr = 0.0005 grs = 1
# Epoch 629 - loss 1.4769  /  val loss 1.9532 lr = 0.0005 grs = 1
# Epoch 630 - loss 1.476  /  val loss 1.9528 lr = 0.0005 grs = 1
# Epoch 631 - loss 1.4751  /  val loss 1.9523 lr = 0.0005 grs = 1
# Epoch 632 - loss 1.4742  /  val loss 1.9519 lr = 0.0005 grs = 1
# Epoch 633 - loss 1.4732  /  val loss 1.9516 lr = 0.0005 grs = 1
# Epoch 634 - loss 1.4723  /  val loss 1.9511 lr = 0.0005 grs = 1
# Epoch 635 - loss 1.4714  /  val loss 1.9507 lr = 0.0005 grs = 1
# Epoch 636 - loss 1.4705  /  val loss 1.9504 lr = 0.0005 grs = 1
# Epoch 637 - loss 1.4696  /  val loss 1.95 lr = 0.0005 grs = 1
# Epoch 638 - loss 1.4687  /  val loss 1.9496 lr = 0.0005 grs = 1
# Epoch 639 - loss 1.4678  /  val loss 1.9492 lr = 0.0005 grs = 1
# Epoch 640 - loss 1.4669  /  val loss 1.9489 lr = 0.0005 grs = 1
# Epoch 641 - loss 1.466  /  val loss 1.9485 lr = 0.0005 grs = 1
# Epoch 642 - loss 1.4651  /  val loss 1.9482 lr = 0.0005 grs = 1
# Epoch 643 - loss 1.4643  /  val loss 1.9478 lr = 0.0005 grs = 1
# Epoch 644 - loss 1.4634  /  val loss 1.9475 lr = 0.0005 grs = 1
# Epoch 645 - loss 1.4625  /  val loss 1.9471 lr = 0.0005 grs = 1
# Epoch 646 - loss 1.4616  /  val loss 1.9467 lr = 0.0005 grs = 1
# Epoch 647 - loss 1.4607  /  val loss 1.9464 lr = 0.0005 grs = 1
# Epoch 648 - loss 1.4599  /  val loss 1.9461 lr = 0.0005 grs = 1
# Epoch 649 - loss 1.459  /  val loss 1.9457 lr = 0.0005 grs = 1
# Epoch 650 - loss 1.4581  /  val loss 1.9453 lr = 0.0005 grs = 1
# Epoch 651 - loss 1.4572  /  val loss 1.9449 lr = 0.0005 grs = 1
# Epoch 652 - loss 1.4564  /  val loss 1.9446 lr = 0.0005 grs = 1
# Epoch 653 - loss 1.4555  /  val loss 1.9443 lr = 0.0005 grs = 1
# Epoch 654 - loss 1.4547  /  val loss 1.9439 lr = 0.0005 grs = 1
# Epoch 655 - loss 1.4538  /  val loss 1.9436 lr = 0.0005 grs = 1
# Epoch 656 - loss 1.453  /  val loss 1.9433 lr = 0.0005 grs = 1
# Epoch 657 - loss 1.4521  /  val loss 1.9429 lr = 0.0005 grs = 1
# Epoch 658 - loss 1.4512  /  val loss 1.9427 lr = 0.0005 grs = 1
# Epoch 659 - loss 1.4504  /  val loss 1.9424 lr = 0.0005 grs = 1
# Epoch 660 - loss 1.4496  /  val loss 1.9421 lr = 0.0005 grs = 1
# Epoch 661 - loss 1.4487  /  val loss 1.9418 lr = 0.0005 grs = 1
# Epoch 662 - loss 1.4479  /  val loss 1.9415 lr = 0.0005 grs = 1
# Epoch 663 - loss 1.447  /  val loss 1.9412 lr = 0.0005 grs = 1
# Epoch 664 - loss 1.4462  /  val loss 1.9409 lr = 0.0005 grs = 1
# Epoch 665 - loss 1.4453  /  val loss 1.9406 lr = 0.0005 grs = 1
# Epoch 666 - loss 1.4445  /  val loss 1.9403 lr = 0.0005 grs = 1
# Epoch 667 - loss 1.4437  /  val loss 1.94 lr = 0.0005 grs = 1
# Epoch 668 - loss 1.4428  /  val loss 1.9397 lr = 0.0005 grs = 1
# Epoch 669 - loss 1.442  /  val loss 1.9394 lr = 0.0005 grs = 1
# Epoch 670 - loss 1.4412  /  val loss 1.9391 lr = 0.0005 grs = 1
# Epoch 671 - loss 1.4404  /  val loss 1.9388 lr = 0.0005 grs = 1
# Epoch 672 - loss 1.4395  /  val loss 1.9385 lr = 0.0005 grs = 1
# Epoch 673 - loss 1.4387  /  val loss 1.9382 lr = 0.0005 grs = 1
# Epoch 674 - loss 1.4379  /  val loss 1.9379 lr = 0.0005 grs = 1
# Epoch 675 - loss 1.4371  /  val loss 1.9376 lr = 0.0005 grs = 1
# Epoch 676 - loss 1.4362  /  val loss 1.9374 lr = 0.0005 grs = 1
# Epoch 677 - loss 1.4354  /  val loss 1.9371 lr = 0.0005 grs = 1
# Epoch 678 - loss 1.4346  /  val loss 1.9368 lr = 0.0005 grs = 1
# Epoch 679 - loss 1.4338  /  val loss 1.9365 lr = 0.0005 grs = 1
# Epoch 680 - loss 1.433  /  val loss 1.9362 lr = 0.0005 grs = 1
# Epoch 681 - loss 1.4321  /  val loss 1.9359 lr = 0.0005 grs = 1
# Epoch 682 - loss 1.4313  /  val loss 1.9356 lr = 0.0005 grs = 1
# Epoch 683 - loss 1.4305  /  val loss 1.9353 lr = 0.0005 grs = 1
# Epoch 684 - loss 1.4297  /  val loss 1.935 lr = 0.0005 grs = 1
# Epoch 685 - loss 1.4289  /  val loss 1.9347 lr = 0.0005 grs = 1
# Epoch 686 - loss 1.4281  /  val loss 1.9344 lr = 0.0005 grs = 1
# Epoch 687 - loss 1.4273  /  val loss 1.9341 lr = 0.0005 grs = 1
# Epoch 688 - loss 1.4264  /  val loss 1.9337 lr = 0.0005 grs = 1
# Epoch 689 - loss 1.4256  /  val loss 1.9334 lr = 0.0005 grs = 1
# Epoch 690 - loss 1.4248  /  val loss 1.9331 lr = 0.0005 grs = 1
# Epoch 691 - loss 1.424  /  val loss 1.9327 lr = 0.0005 grs = 1
# Epoch 692 - loss 1.4232  /  val loss 1.9323 lr = 0.0005 grs = 1
# Epoch 693 - loss 1.4224  /  val loss 1.932 lr = 0.0005 grs = 1
# Epoch 694 - loss 1.4216  /  val loss 1.9316 lr = 0.0005 grs = 1
# Epoch 695 - loss 1.4208  /  val loss 1.9313 lr = 0.0005 grs = 1
# Epoch 696 - loss 1.42  /  val loss 1.9309 lr = 0.0005 grs = 1
# Epoch 697 - loss 1.4191  /  val loss 1.9306 lr = 0.0005 grs = 1
# Epoch 698 - loss 1.4183  /  val loss 1.9302 lr = 0.0005 grs = 1
# Epoch 699 - loss 1.4175  /  val loss 1.9298 lr = 0.0005 grs = 1
# Epoch 700 - loss 1.4167  /  val loss 1.9294 lr = 0.0005 grs = 1
# Epoch 701 - loss 1.4159  /  val loss 1.9291 lr = 0.0005 grs = 1
# Epoch 702 - loss 1.4151  /  val loss 1.9287 lr = 0.0005 grs = 1
# Epoch 703 - loss 1.4143  /  val loss 1.9283 lr = 0.0005 grs = 1
# Epoch 704 - loss 1.4135  /  val loss 1.9279 lr = 0.0005 grs = 1
# Epoch 705 - loss 1.4127  /  val loss 1.9274 lr = 0.0005 grs = 1
# Epoch 706 - loss 1.4119  /  val loss 1.9271 lr = 0.0005 grs = 1
# Epoch 707 - loss 1.4111  /  val loss 1.9266 lr = 0.0005 grs = 1
# Epoch 708 - loss 1.4103  /  val loss 1.9264 lr = 0.0005 grs = 1
# Epoch 709 - loss 1.4094  /  val loss 1.9259 lr = 0.0005 grs = 1
# Epoch 710 - loss 1.4086  /  val loss 1.9258 lr = 0.0005 grs = 1
# Epoch 711 - loss 1.4078  /  val loss 1.925 lr = 0.0005 grs = 1
# Epoch 712 - loss 1.407  /  val loss 1.9255 lr = 0.0005 grs = 1
# Epoch 713 - loss 1.4063  /  val loss 1.9239 lr = 0.0005 grs = 1
# Epoch 714 - loss 1.4055  /  val loss 1.9261 lr = 0.0005 grs = 1
# Epoch 715 - loss 1.4047  /  val loss 1.9215 lr = 0.0005 grs = 1
# Epoch 716 - loss 1.4042  /  val loss 1.9304 lr = 0.0005 grs = 1
# Epoch 717 - loss 1.4041  /  val loss 1.9169 lr = 0.0005 grs = 1
# Epoch 718 - loss 1.4062  /  val loss 1.9561 lr = 0.0005 grs = 1
# Epoch 719 - loss 1.415  /  val loss 1.929 lr = 0.0005 grs = 1
# Epoch 720 - loss 1.443  /  val loss 2.0672 lr = 0.0005 grs = 1
# Epoch 721 - loss 1.4966  /  val loss 2.0039 lr = 0.0005 grs = 1
# Epoch 722 - loss 1.5494  /  val loss 2.0452 lr = 0.0005 grs = 1
# Epoch 723 - loss 1.4927  /  val loss 1.9077 lr = 0.0005 grs = 1
# Epoch 724 - loss 1.4083  /  val loss 1.9129 lr = 0.0005 grs = 1
# Epoch 725 - loss 1.442  /  val loss 2.0043 lr = 0.0005 grs = 1
# Epoch 726 - loss 1.47  /  val loss 1.9134 lr = 0.0005 grs = 1
# Epoch 727 - loss 1.4154  /  val loss 1.9026 lr = 0.0005 grs = 1
# Epoch 728 - loss 1.4204  /  val loss 1.9772 lr = 0.0005 grs = 1
# Epoch 729 - loss 1.4472  /  val loss 1.9206 lr = 0.0005 grs = 1
# Epoch 730 - loss 1.4129  /  val loss 1.9071 lr = 0.0005 grs = 1
# Epoch 731 - loss 1.4087  /  val loss 1.9662 lr = 0.0005 grs = 1
# Epoch 732 - loss 1.4321  /  val loss 1.9258 lr = 0.0005 grs = 1
# Epoch 733 - loss 1.4102  /  val loss 1.9137 lr = 0.0005 grs = 1
# Epoch 734 - loss 1.3993  /  val loss 1.9538 lr = 0.0005 grs = 1
# Epoch 735 - loss 1.4187  /  val loss 1.9238 lr = 0.0005 grs = 1
# Epoch 736 - loss 1.4081  /  val loss 1.9176 lr = 0.0005 grs = 1
# Epoch 737 - loss 1.3933  /  val loss 1.9367 lr = 0.0005 grs = 1
# Epoch 738 - loss 1.405  /  val loss 1.9187 lr = 0.0005 grs = 1
# Epoch 739 - loss 1.4064  /  val loss 1.9247 lr = 0.0005 grs = 1
# Epoch 740 - loss 1.3927  /  val loss 1.9189 lr = 0.0005 grs = 1
# Epoch 741 - loss 1.3927  /  val loss 1.9128 lr = 0.0005 grs = 1
# Epoch 742 - loss 1.4004  /  val loss 1.9367 lr = 0.0005 grs = 1
# Epoch 743 - loss 1.3956  /  val loss 1.9081 lr = 0.0005 grs = 1
# Epoch 744 - loss 1.3874  /  val loss 1.911 lr = 0.0005 grs = 1
# Epoch 745 - loss 1.3894  /  val loss 1.9395 lr = 0.0005 grs = 1
# Epoch 746 - loss 1.3934  /  val loss 1.9062 lr = 0.0005 grs = 1
# Epoch 747 - loss 1.3896  /  val loss 1.9172 lr = 0.0005 grs = 1
# Epoch 748 - loss 1.3834  /  val loss 1.927 lr = 0.0005 grs = 1
# Epoch 749 - loss 1.3847  /  val loss 1.9072 lr = 0.0005 grs = 1
# ...
# Epoch 2773 - loss 0.83378  /  val loss 1.7997 lr = 3.125e-05 grs = 1
# Epoch 2774 - loss 0.83372  /  val loss 1.7997 lr = 3.125e-05 grs = 1
# Epoch 2775 - loss 0.83366  /  val loss 1.7997 lr = 3.125e-05 grs = 1
# Epoch 2776 - loss 0.83361  /  val loss 1.7997 lr = 3.125e-05 grs = 1
# Epoch 2777 - loss 0.83355  /  val loss 1.7997 lr = 3.125e-05 grs = 1
# Epoch 2778 - loss 0.8335  /  val loss 1.7997 lr = 3.125e-05 grs = 1
# Epoch 2779 - loss 0.83344  /  val loss 1.7997 lr = 3.125e-05 grs = 1
# Epoch 2780 - loss 0.83338  /  val loss 1.7997 lr = 3.125e-05 grs = 1
# Epoch 2781 - loss 0.83333  /  val loss 1.7997 lr = 3.125e-05 grs = 1
# Epoch 2782 - loss 0.83327  /  val loss 1.7998 lr = 3.125e-05 grs = 1
# Epoch 2783 - loss 0.83321  /  val loss 1.7998 lr = 3.125e-05 grs = 1
# Epoch 2784 - loss 0.83316  /  val loss 1.7998 lr = 3.125e-05 grs = 1
# Epoch 2785 - loss 0.8331  /  val loss 1.7998 lr = 3.125e-05 grs = 1
# Epoch 2786 - loss 0.83304  /  val loss 1.7998 lr = 3.125e-05 grs = 1
# Epoch 2787 - loss 0.83299  /  val loss 1.7998 lr = 3.125e-05 grs = 1
# Epoch 2788 - loss 0.83293  /  val loss 1.7998 lr = 3.125e-05 grs = 1
# Epoch 2789 - loss 0.83287  /  val loss 1.7998 lr = 3.125e-05 grs = 1
# Epoch 2790 - loss 0.83282  /  val loss 1.7999 lr = 3.125e-05 grs = 1
# Epoch 2791 - loss 0.83276  /  val loss 1.7999 lr = 3.125e-05 grs = 1
# Epoch 2792 - loss 0.8327  /  val loss 1.7999 lr = 3.125e-05 grs = 1
# Epoch 2793 - loss 0.83265  /  val loss 1.7999 lr = 3.125e-05 grs = 1
# Epoch 2794 - loss 0.83259  /  val loss 1.7999 lr = 3.125e-05 grs = 1
# Epoch 2795 - loss 0.83253  /  val loss 1.7999 lr = 3.125e-05 grs = 1
# Epoch 2796 - loss 0.83248  /  val loss 1.7999 lr = 3.125e-05 grs = 1
# Epoch 2797 - loss 0.83242  /  val loss 1.7999 lr = 3.125e-05 grs = 1
# Epoch 2798 - loss 0.83236  /  val loss 1.8 lr = 3.125e-05 grs = 1
# Epoch 2799 - loss 0.83231  /  val loss 1.8 lr = 3.125e-05 grs = 1
# Epoch 2800 - loss 0.83225  /  val loss 1.8 lr = 3.125e-05 grs = 1
# Epoch 2801 - loss 0.83219  /  val loss 1.8 lr = 3.125e-05 grs = 1
# Epoch 2802 - loss 0.83214  /  val loss 1.8 lr = 3.125e-05 grs = 1
# Epoch 2803 - loss 0.83208  /  val loss 1.8 lr = 3.125e-05 grs = 1
# Epoch 2804 - loss 0.83202  /  val loss 1.8 lr = 3.125e-05 grs = 1
# Epoch 2805 - loss 0.83197  /  val loss 1.8 lr = 3.125e-05 grs = 1
# Epoch 2806 - loss 0.83191  /  val loss 1.8 lr = 3.125e-05 grs = 1
# Epoch 2807 - loss 0.83185  /  val loss 1.8001 lr = 3.125e-05 grs = 1
# Epoch 2808 - loss 0.83179  /  val loss 1.8001 lr = 3.125e-05 grs = 1
# Epoch 2809 - loss 0.83174  /  val loss 1.8001 lr = 3.125e-05 grs = 1
# Epoch 2810 - loss 0.83168  /  val loss 1.8001 lr = 3.125e-05 grs = 1
# Epoch 2811 - loss 0.83162  /  val loss 1.8001 lr = 3.125e-05 grs = 1
# Epoch 2812 - loss 0.83157  /  val loss 1.8001 lr = 3.125e-05 grs = 1
# Epoch 2813 - loss 0.83151  /  val loss 1.8001 lr = 3.125e-05 grs = 1
# Epoch 2814 - loss 0.83145  /  val loss 1.8001 lr = 3.125e-05 grs = 1
# Epoch 2815 - loss 0.8314  /  val loss 1.8002 lr = 3.125e-05 grs = 1
# Epoch 2816 - loss 0.83134  /  val loss 1.8002 lr = 3.125e-05 grs = 1
# Epoch 2817 - loss 0.83128  /  val loss 1.8002 lr = 3.125e-05 grs = 1
# Epoch 2818 - loss 0.83122  /  val loss 1.8002 lr = 3.125e-05 grs = 1
# Epoch 2819 - loss 0.83117  /  val loss 1.8002 lr = 3.125e-05 grs = 1
# Epoch 2820 - loss 0.83111  /  val loss 1.8002 lr = 3.125e-05 grs = 1
# Epoch 2821 - loss 0.83105  /  val loss 1.8002 lr = 3.125e-05 grs = 1
# Epoch 2822 - loss 0.831  /  val loss 1.8002 lr = 3.125e-05 grs = 1
# Epoch 2823 - loss 0.83094  /  val loss 1.8003 lr = 3.125e-05 grs = 1
# Epoch 2824 - loss 0.83088  /  val loss 1.8003 lr = 3.125e-05 grs = 1
# Epoch 2825 - loss 0.83082  /  val loss 1.8003 lr = 3.125e-05 grs = 1
# Epoch 2826 - loss 0.83077  /  val loss 1.8003 lr = 3.125e-05 grs = 1
# Epoch 2827 - loss 0.83071  /  val loss 1.8003 lr = 3.125e-05 grs = 1
# Epoch 2828 - loss 0.83065  /  val loss 1.8003 lr = 3.125e-05 grs = 1
# Epoch 2829 - loss 0.83059  /  val loss 1.8003 lr = 3.125e-05 grs = 1
# Epoch 2830 - loss 0.83054  /  val loss 1.8003 lr = 3.125e-05 grs = 1
# Epoch 2831 - loss 0.83048  /  val loss 1.8004 lr = 3.125e-05 grs = 1
# Epoch 2832 - loss 0.83042  /  val loss 1.8004 lr = 3.125e-05 grs = 1
# Epoch 2833 - loss 0.83036  /  val loss 1.8004 lr = 3.125e-05 grs = 1
# Epoch 2834 - loss 0.83031  /  val loss 1.8004 lr = 3.125e-05 grs = 1
# Epoch 2835 - loss 0.83025  /  val loss 1.8004 lr = 3.125e-05 grs = 1
# Epoch 2836 - loss 0.83019  /  val loss 1.8004 lr = 3.125e-05 grs = 1
# Epoch 2837 - loss 0.83013  /  val loss 1.8004 lr = 3.125e-05 grs = 1
# Epoch 2838 - loss 0.83008  /  val loss 1.8004 lr = 3.125e-05 grs = 1
# Epoch 2839 - loss 0.83002  /  val loss 1.8005 lr = 3.125e-05 grs = 1
# Epoch 2840 - loss 0.82996  /  val loss 1.8005 lr = 3.125e-05 grs = 1
# Epoch 2841 - loss 0.8299  /  val loss 1.8005 lr = 3.125e-05 grs = 1
# Epoch 2842 - loss 0.82985  /  val loss 1.8005 lr = 3.125e-05 grs = 1
# Epoch 2843 - loss 0.82979  /  val loss 1.8005 lr = 3.125e-05 grs = 1
# Epoch 2844 - loss 0.82973  /  val loss 1.8005 lr = 3.125e-05 grs = 1
# Epoch 2845 - loss 0.82967  /  val loss 1.8005 lr = 3.125e-05 grs = 1
# Epoch 2846 - loss 0.82962  /  val loss 1.8005 lr = 3.125e-05 grs = 1
# Epoch 2847 - loss 0.82956  /  val loss 1.8006 lr = 3.125e-05 grs = 1
# Epoch 2848 - loss 0.8295  /  val loss 1.8006 lr = 3.125e-05 grs = 1
# Epoch 2849 - loss 0.82944  /  val loss 1.8006 lr = 3.125e-05 grs = 1
# Epoch 2850 - loss 0.82939  /  val loss 1.8006 lr = 3.125e-05 grs = 1
# Epoch 2851 - loss 0.82933  /  val loss 1.8006 lr = 3.125e-05 grs = 1
# Epoch 2852 - loss 0.82927  /  val loss 1.8006 lr = 3.125e-05 grs = 1
# Epoch 2853 - loss 0.82921  /  val loss 1.8006 lr = 3.125e-05 grs = 1
# Epoch 2854 - loss 0.82916  /  val loss 1.8006 lr = 3.125e-05 grs = 1
# Epoch 2855 - loss 0.8291  /  val loss 1.8007 lr = 3.125e-05 grs = 1
# Epoch 2856 - loss 0.82904  /  val loss 1.8007 lr = 3.125e-05 grs = 1
# Epoch 2857 - loss 0.82898  /  val loss 1.8007 lr = 3.125e-05 grs = 1
# Epoch 2858 - loss 0.82892  /  val loss 1.8007 lr = 3.125e-05 grs = 1
# Epoch 2859 - loss 0.82887  /  val loss 1.8007 lr = 3.125e-05 grs = 1
# Epoch 2860 - loss 0.82881  /  val loss 1.8007 lr = 3.125e-05 grs = 1
# Epoch 2861 - loss 0.82875  /  val loss 1.8007 lr = 3.125e-05 grs = 1
# Epoch 2862 - loss 0.82869  /  val loss 1.8008 lr = 3.125e-05 grs = 1
# Epoch 2863 - loss 0.82863  /  val loss 1.8008 lr = 3.125e-05 grs = 1
# Epoch 2864 - loss 0.82858  /  val loss 1.8008 lr = 3.125e-05 grs = 1
# Epoch 2865 - loss 0.82852  /  val loss 1.8008 lr = 3.125e-05 grs = 1
# Epoch 2866 - loss 0.82846  /  val loss 1.8008 lr = 3.125e-05 grs = 1
# Epoch 2867 - loss 0.8284  /  val loss 1.8008 lr = 3.125e-05 grs = 1
# Epoch 2868 - loss 0.82834  /  val loss 1.8008 lr = 3.125e-05 grs = 1
# Epoch 2869 - loss 0.82829  /  val loss 1.8008 lr = 3.125e-05 grs = 1
# Epoch 2870 - loss 0.82823  /  val loss 1.8009 lr = 3.125e-05 grs = 1
# Epoch 2871 - loss 0.82817  /  val loss 1.8009 lr = 3.125e-05 grs = 1
# Epoch 2872 - loss 0.82811  /  val loss 1.8009 lr = 3.125e-05 grs = 1
# Epoch 2873 - loss 0.82805  /  val loss 1.8009 lr = 3.125e-05 grs = 1
# Epoch 2874 - loss 0.828  /  val loss 1.8009 lr = 3.125e-05 grs = 1
# Epoch 2875 - loss 0.82794  /  val loss 1.8009 lr = 3.125e-05 grs = 1
# Epoch 2876 - loss 0.82788  /  val loss 1.8009 lr = 3.125e-05 grs = 1
# Epoch 2877 - loss 0.82782  /  val loss 1.801 lr = 3.125e-05 grs = 1
# Epoch 2878 - loss 0.82776  /  val loss 1.801 lr = 3.125e-05 grs = 1
# Epoch 2879 - loss 0.8277  /  val loss 1.801 lr = 3.125e-05 grs = 1
# Epoch 2880 - loss 0.82765  /  val loss 1.801 lr = 3.125e-05 grs = 1
# Epoch 2881 - loss 0.82759  /  val loss 1.801 lr = 3.125e-05 grs = 1
# Epoch 2882 - loss 0.82753  /  val loss 1.801 lr = 3.125e-05 grs = 1
# Epoch 2883 - loss 0.82747  /  val loss 1.801 lr = 3.125e-05 grs = 1
# Epoch 2884 - loss 0.82741  /  val loss 1.801 lr = 3.125e-05 grs = 1
# Epoch 2885 - loss 0.82736  /  val loss 1.8011 lr = 3.125e-05 grs = 1
# Epoch 2886 - loss 0.8273  /  val loss 1.8011 lr = 3.125e-05 grs = 1
# Epoch 2887 - loss 0.82724  /  val loss 1.8011 lr = 3.125e-05 grs = 1
# Epoch 2888 - loss 0.82718  /  val loss 1.8011 lr = 3.125e-05 grs = 1
# Epoch 2889 - loss 0.82712  /  val loss 1.8011 lr = 3.125e-05 grs = 1
# Epoch 2890 - loss 0.82706  /  val loss 1.8011 lr = 3.125e-05 grs = 1
# Epoch 2891 - loss 0.827  /  val loss 1.8011 lr = 3.125e-05 grs = 1
# Epoch 2892 - loss 0.82695  /  val loss 1.8012 lr = 3.125e-05 grs = 1
# Epoch 2893 - loss 0.82689  /  val loss 1.8012 lr = 3.125e-05 grs = 1
# Epoch 2894 - loss 0.82683  /  val loss 1.8012 lr = 3.125e-05 grs = 1
# Epoch 2895 - loss 0.82677  /  val loss 1.8012 lr = 3.125e-05 grs = 1
# Epoch 2896 - loss 0.82671  /  val loss 1.8012 lr = 3.125e-05 grs = 1
# Epoch 2897 - loss 0.82665  /  val loss 1.8012 lr = 3.125e-05 grs = 1
# Epoch 2898 - loss 0.82659  /  val loss 1.8012 lr = 3.125e-05 grs = 1
# Epoch 2899 - loss 0.82654  /  val loss 1.8013 lr = 3.125e-05 grs = 1
# Epoch 2900 - loss 0.82648  /  val loss 1.8013 lr = 3.125e-05 grs = 1
# Epoch 2901 - loss 0.82642  /  val loss 1.8013 lr = 3.125e-05 grs = 1
# Epoch 2902 - loss 0.82636  /  val loss 1.8013 lr = 3.125e-05 grs = 1
# Epoch 2903 - loss 0.8263  /  val loss 1.8013 lr = 3.125e-05 grs = 1
# Epoch 2904 - loss 0.82624  /  val loss 1.8013 lr = 3.125e-05 grs = 1
# Epoch 2905 - loss 0.82618  /  val loss 1.8013 lr = 3.125e-05 grs = 1
# Epoch 2906 - loss 0.82613  /  val loss 1.8013 lr = 3.125e-05 grs = 1
# Epoch 2907 - loss 0.82607  /  val loss 1.8014 lr = 3.125e-05 grs = 1
# Epoch 2908 - loss 0.82601  /  val loss 1.8014 lr = 3.125e-05 grs = 1
# Epoch 2909 - loss 0.82595  /  val loss 1.8014 lr = 3.125e-05 grs = 1
# Epoch 2910 - loss 0.82589  /  val loss 1.8014 lr = 3.125e-05 grs = 1
# Epoch 2911 - loss 0.82583  /  val loss 1.8014 lr = 3.125e-05 grs = 1
# Epoch 2912 - loss 0.82577  /  val loss 1.8014 lr = 3.125e-05 grs = 1
# Epoch 2913 - loss 0.82571  /  val loss 1.8014 lr = 3.125e-05 grs = 1
# Epoch 2914 - loss 0.82565  /  val loss 1.8015 lr = 3.125e-05 grs = 1
# Epoch 2915 - loss 0.8256  /  val loss 1.8015 lr = 3.125e-05 grs = 1
# Epoch 2916 - loss 0.82554  /  val loss 1.8015 lr = 3.125e-05 grs = 1
# Epoch 2917 - loss 0.82548  /  val loss 1.8015 lr = 3.125e-05 grs = 1
# Epoch 2918 - loss 0.82542  /  val loss 1.8015 lr = 3.125e-05 grs = 1
# Epoch 2919 - loss 0.82536  /  val loss 1.8015 lr = 3.125e-05 grs = 1
# Epoch 2920 - loss 0.8253  /  val loss 1.8015 lr = 3.125e-05 grs = 1
# Epoch 2921 - loss 0.82524  /  val loss 1.8016 lr = 3.125e-05 grs = 1
# Epoch 2922 - loss 0.82518  /  val loss 1.8016 lr = 3.125e-05 grs = 1
# Epoch 2923 - loss 0.82512  /  val loss 1.8016 lr = 3.125e-05 grs = 1
# Epoch 2924 - loss 0.82506  /  val loss 1.8016 lr = 3.125e-05 grs = 1
# Epoch 2925 - loss 0.82501  /  val loss 1.8016 lr = 3.125e-05 grs = 1
# Epoch 2926 - loss 0.82495  /  val loss 1.8016 lr = 3.125e-05 grs = 1
# Epoch 2927 - loss 0.82489  /  val loss 1.8016 lr = 3.125e-05 grs = 1
# Epoch 2928 - loss 0.82483  /  val loss 1.8017 lr = 3.125e-05 grs = 1
# Epoch 2929 - loss 0.82477  /  val loss 1.8017 lr = 3.125e-05 grs = 1
# Epoch 2930 - loss 0.82471  /  val loss 1.8017 lr = 3.125e-05 grs = 1
# Epoch 2931 - loss 0.82465  /  val loss 1.8017 lr = 3.125e-05 grs = 1
# Epoch 2932 - loss 0.82459  /  val loss 1.8017 lr = 3.125e-05 grs = 1
# Epoch 2933 - loss 0.82453  /  val loss 1.8017 lr = 3.125e-05 grs = 1
# Epoch 2934 - loss 0.82447  /  val loss 1.8017 lr = 3.125e-05 grs = 1
# Epoch 2935 - loss 0.82441  /  val loss 1.8018 lr = 3.125e-05 grs = 1
# Epoch 2936 - loss 0.82435  /  val loss 1.8018 lr = 3.125e-05 grs = 1
# Epoch 2937 - loss 0.82429  /  val loss 1.8018 lr = 3.125e-05 grs = 1
# Epoch 2938 - loss 0.82423  /  val loss 1.8018 lr = 3.125e-05 grs = 1
# Epoch 2939 - loss 0.82418  /  val loss 1.8018 lr = 3.125e-05 grs = 1
# Epoch 2940 - loss 0.82412  /  val loss 1.8018 lr = 3.125e-05 grs = 1
# Epoch 2941 - loss 0.82406  /  val loss 1.8018 lr = 3.125e-05 grs = 1
# Epoch 2942 - loss 0.824  /  val loss 1.8019 lr = 3.125e-05 grs = 1
# Epoch 2943 - loss 0.82394  /  val loss 1.8019 lr = 3.125e-05 grs = 1
# Epoch 2944 - loss 0.82388  /  val loss 1.8019 lr = 3.125e-05 grs = 1
# Epoch 2945 - loss 0.82382  /  val loss 1.8019 lr = 3.125e-05 grs = 1
# Epoch 2946 - loss 0.82376  /  val loss 1.8019 lr = 3.125e-05 grs = 1
# Epoch 2947 - loss 0.8237  /  val loss 1.8019 lr = 3.125e-05 grs = 1
# Epoch 2948 - loss 0.82364  /  val loss 1.8019 lr = 3.125e-05 grs = 1
# Epoch 2949 - loss 0.82358  /  val loss 1.802 lr = 3.125e-05 grs = 1
# Epoch 2950 - loss 0.82352  /  val loss 1.802 lr = 3.125e-05 grs = 1
# Epoch 2951 - loss 0.82346  /  val loss 1.802 lr = 3.125e-05 grs = 1
# Epoch 2952 - loss 0.8234  /  val loss 1.802 lr = 3.125e-05 grs = 1
# Epoch 2953 - loss 0.82334  /  val loss 1.802 lr = 3.125e-05 grs = 1
# Epoch 2954 - loss 0.82328  /  val loss 1.802 lr = 3.125e-05 grs = 1
# Epoch 2955 - loss 0.82322  /  val loss 1.802 lr = 3.125e-05 grs = 1
# Epoch 2956 - loss 0.82316  /  val loss 1.8021 lr = 3.125e-05 grs = 1
# Epoch 2957 - loss 0.8231  /  val loss 1.8021 lr = 3.125e-05 grs = 1
# Epoch 2958 - loss 0.82304  /  val loss 1.8021 lr = 3.125e-05 grs = 1
# Epoch 2959 - loss 0.82298  /  val loss 1.8021 lr = 3.125e-05 grs = 1
# Epoch 2960 - loss 0.82292  /  val loss 1.8021 lr = 3.125e-05 grs = 1
# Epoch 2961 - loss 0.82286  /  val loss 1.8021 lr = 3.125e-05 grs = 1
# Epoch 2962 - loss 0.8228  /  val loss 1.8022 lr = 3.125e-05 grs = 1
# Epoch 2963 - loss 0.82275  /  val loss 1.8022 lr = 3.125e-05 grs = 1
# Epoch 2964 - loss 0.82269  /  val loss 1.8022 lr = 3.125e-05 grs = 1
# Epoch 2965 - loss 0.82263  /  val loss 1.8022 lr = 3.125e-05 grs = 1
# Epoch 2966 - loss 0.82257  /  val loss 1.8022 lr = 3.125e-05 grs = 1
# Epoch 2967 - loss 0.82251  /  val loss 1.8022 lr = 3.125e-05 grs = 1
# Epoch 2968 - loss 0.82245  /  val loss 1.8022 lr = 3.125e-05 grs = 1
# Epoch 2969 - loss 0.82239  /  val loss 1.8023 lr = 3.125e-05 grs = 1
# Epoch 2970 - loss 0.82233  /  val loss 1.8023 lr = 3.125e-05 grs = 1
# Epoch 2971 - loss 0.82227  /  val loss 1.8023 lr = 3.125e-05 grs = 1
# Epoch 2972 - loss 0.82221  /  val loss 1.8023 lr = 3.125e-05 grs = 1
# Epoch 2973 - loss 0.82215  /  val loss 1.8023 lr = 3.125e-05 grs = 1
# Epoch 2974 - loss 0.82209  /  val loss 1.8023 lr = 3.125e-05 grs = 1
# Epoch 2975 - loss 0.82203  /  val loss 1.8024 lr = 3.125e-05 grs = 1
# Epoch 2976 - loss 0.82197  /  val loss 1.8024 lr = 3.125e-05 grs = 1
# Epoch 2977 - loss 0.82191  /  val loss 1.8024 lr = 3.125e-05 grs = 1
# Epoch 2978 - loss 0.82185  /  val loss 1.8024 lr = 3.125e-05 grs = 1
# Epoch 2979 - loss 0.82179  /  val loss 1.8024 lr = 3.125e-05 grs = 1
# Epoch 2980 - loss 0.82173  /  val loss 1.8024 lr = 3.125e-05 grs = 1
# Epoch 2981 - loss 0.82167  /  val loss 1.8024 lr = 3.125e-05 grs = 1
# Epoch 2982 - loss 0.82161  /  val loss 1.8025 lr = 3.125e-05 grs = 1
# Epoch 2983 - loss 0.82155  /  val loss 1.8025 lr = 3.125e-05 grs = 1
# Epoch 2984 - loss 0.82149  /  val loss 1.8025 lr = 3.125e-05 grs = 1
# Epoch 2985 - loss 0.82143  /  val loss 1.8025 lr = 3.125e-05 grs = 1
# Epoch 2986 - loss 0.82137  /  val loss 1.8025 lr = 3.125e-05 grs = 1
# Epoch 2987 - loss 0.82131  /  val loss 1.8025 lr = 3.125e-05 grs = 1
# Epoch 2988 - loss 0.82125  /  val loss 1.8026 lr = 3.125e-05 grs = 1
# Epoch 2989 - loss 0.82119  /  val loss 1.8026 lr = 3.125e-05 grs = 1
# Epoch 2990 - loss 0.82112  /  val loss 1.8026 lr = 3.125e-05 grs = 1
# Epoch 2991 - loss 0.82106  /  val loss 1.8026 lr = 3.125e-05 grs = 1
# Epoch 2992 - loss 0.821  /  val loss 1.8026 lr = 3.125e-05 grs = 1
# Epoch 2993 - loss 0.82094  /  val loss 1.8026 lr = 3.125e-05 grs = 1
# Epoch 2994 - loss 0.82088  /  val loss 1.8027 lr = 3.125e-05 grs = 1
# Epoch 2995 - loss 0.82082  /  val loss 1.8027 lr = 3.125e-05 grs = 1
# Epoch 2996 - loss 0.82076  /  val loss 1.8027 lr = 3.125e-05 grs = 1
# Epoch 2997 - loss 0.8207  /  val loss 1.8027 lr = 3.125e-05 grs = 1
# Epoch 2998 - loss 0.82064  /  val loss 1.8027 lr = 3.125e-05 grs = 1
# Epoch 2999 - loss 0.82058  /  val loss 1.8027 lr = 3.125e-05 grs = 1
# !!!!!!!!!!!!!!!cahnge lr to` 1.5625e-05
# Epoch 3000 - loss 0.82052  /  val loss 1.8027 lr = 1.5625e-05 grs = 1
# Training done!

# %%
# найти лучшую сеть - с минимальным значением ф-ции потерь и загрузить ее
mdls_names_lst = os.listdir(models_dir)
best_losses = [float(name.split("_")[-1][:-4])
               for name in mdls_names_lst]  # список наменьших лоссов
print(f"best_losses {best_losses}")
best_mdl_name = [mdl_name for mdl_name in mdls_names_lst if str(
    min(best_losses)) in mdl_name][0]
model = torch.load(models_dir + "/" + best_mdl_name)
print(f"best model {models_dir + '/' + best_mdl_name} loaded")

# конвертация моели в libtorch формат 
if 0:  # train_mode:
    # тестовый тензор для генерации модели без него не работает
    example = torch.rand(1, 1, dense_dim, dense_dim)

    # Use torch.jit.trace to generate a torch.jit.ScriptModule via tracing.
    traced_script_module = torch.jit.trace(model, example)
    output = traced_script_module(torch.ones(1, 1, dense_dim))
    # print(f"output[0, :5] {output[0, :5]}")
    pt_model_name = f"pedro_{dense_dim}_{str(min(best_losses))}.pt"
    # save it also in orthoplatform Designer bin folder
    path_ = r'C:\Projects\Spark\orthoplatform\Build\Bin\SparkDesigner\Release\Resources\MLModels\Autosetup/' + \
        f"Pedro{dense_dim}.pt"  # Pedro3Jaw480
    # traced_script_module.save(path_)

    import datetime
    print(
        f"libtorch model {libtorch_models_dir}/{pt_model_name} saved. datetime{datetime.datetime.now()}")
# Out:
# best_losses [1.847, 1.847, 1.847, 1.847, 1.847, 1.847, 1.847, 1.847, 1.847, 1.847, 1.846, 1.846, 1.846, 1.846, 1.846, 1.846, 1.846, 1.846, 1.846, 1.846, 1.846, 1.846, 1.845, 1.845, 1.845, 1.845, 1.845, 1.845, 1.845, 1.845, 1.845, 1.845, 1.845, 1.845, 1.844, 1.844, 1.844, 1.844, 1.844, 1.844, 1.844, 1.844, 1.844, 1.844, 1.844, 1.843, 1.843, 1.843, 1.843, 1.843, 1.843, 1.843, 1.843, 1.843, 1.843, 1.843, 1.843, 1.842, 1.842, 1.842, 1.842, 1.842, 1.842, 1.842, 1.842, 1.842, 1.842, 1.842, 1.842, 1.841, 1.841, 1.841, 1.841, 1.841, 1.841, 1.841, 1.841, 1.841, 1.841, 1.841, 1.841, 1.84, 1.84, 1.84, 1.84, 1.84, 1.84, 1.84, 1.84, 1.84, 1.84, 1.84, 1.839, 1.839, 1.839, 1.839, 1.839, 1.839, 1.839, 1.839, 1.839, 1.839, 1.838, 1.838, 1.838, 1.838, 1.838, 1.838, 1.838, 1.838, 1.838, 1.838, 1.837, 1.837, 1.837, 1.837, 1.837, 1.837, 1.837, 1.837, 1.837, 1.836, 1.836, 1.836, 1.836, 1.836, 1.836, 1.836, 1.836, 1.835, 1.835, 1.835, 1.835, 1.835, 1.835, 1.835, 1.835, 1.835, 1.834, 1.834, 1.834, 1.834, 1.834, 1.834, 1.834, 1.834, 1.833, 1.833, 1.833, 1.833, 1.833, 1.833, 1.833, 1.833, 1.833, 1.832, 1.832, 1.832, 1.832, 1.832, 1.832, 1.832, 1.832, 1.831, 1.831, 1.831, 1.831, 1.831, 1.831, 1.83, 1.83, 1.83, 1.83, 1.83, 1.83, 1.829, 1.829, 1.829, 1.829, 1.829, 1.829, 1.828, 1.828, 1.828, 1.828, 1.828, 1.828, 1.828, 1.828, 1.828, 1.827, 1.827, 1.827, 1.827, 1.827, 1.827, 1.827, 1.827, 1.827, 1.826, 1.826, 1.826, 1.826, 1.826, 1.826, 1.826, 1.826, 1.825, 1.825, 1.825, 1.825, 1.825, 1.825, 1.825, 1.825, 1.825, 1.825, 1.824, 1.824, 1.824, 1.824, 1.824, 1.824, 1.824, 1.824, 1.823, 1.823, 1.823, 1.823, 1.823, 1.823, 1.823, 1.823, 1.822, 1.822, 1.822, 1.822, 1.822, 1.822, 1.822, 1.822, 1.822, 1.821, 1.821, 1.821, 1.821, 1.821, 1.821, 1.821, 1.821, 1.82, 1.82, 1.82, 1.82, 1.82, 1.82, 1.82, 1.82, 1.82, 1.819, 1.819, 1.819, 1.819, 1.819, 1.819, 1.819, 1.819, 1.818, 1.818, 1.818, 1.818, 1.818, 1.817, 1.815, 1.812, 1.808, 1.798, 1.792, 1.784, 1.938, 1.938, 1.937, 1.937, 1.937, 1.937, 1.936, 1.936, 1.936, 1.935, 1.935, 1.935, 1.934, 1.934, 1.934, 1.933, 1.933, 1.933, 1.932, 1.932, 1.932, 1.931, 1.931, 1.931, 1.93, 1.93, 1.929, 1.929, 1.929, 1.928, 1.928, 1.927, 1.927, 1.927, 1.926, 1.926, 1.926, 1.925, 1.924, 1.922, 1.917, 1.908, 1.903, 1.901, 1.898, 1.893, 1.887, 1.886, 1.885, 1.883, 1.882, 1.879, 1.874, 1.874, 1.873, 1.861, 1.847]
# best model models/ep1402_1.784.pth loaded

# %% [markdown]
# ### Evaluating

# %%
# Evaluating the model
# проверка кейса 100497.oas
if 0:
    # case100497 = set_gen_fr_csv_pd_ver3(csv_fpath, 1, one_case="100497.oas")
    # loader = DataLoader(case100497, batch_size=1) # лодырь только для одного кейса - для теста
    case = set_gen_fr_csv_pd_ver3(csv_fpath, 1, one_case="909346.oas")
    # лодырь только для одного кейса - для теста
    loader = DataLoader(case, batch_size=1)

else:
    loader = test_loader  # one_loader # test_loader

assert len(test_loader) > 0
print(f"loader batch size = {loader.batch_size} batches in it = {len(loader)}")
T1, T2 = None, None
# print(f"train_loader batch size = {train_loader.batch_size} batches in it = {len(train_loader)}")
with torch.no_grad():
    # помни! предикт идет по батчам. если перебираешь все, то в pred будет последний батч.
    # его размер будет остатком от деления размера датасета на размер батча!
    # print(f" test_loader.batch_sampler \n{test_loader.__getitem__}")
    # итерируемся по всем кейсам единственного батча ( см ниже break )
    for T1, T2 in loader:
        # почему так сделано - data_loader - хитрый объект. взять первый батч как первый член из списка не выходит.
        # print(f"len X {len(X)}")
        # T1[:,105:120]=0 # заменяет нулями 37-й(17-й) зуб во всех кейсах батча, от этого корежится предикт
        #                         X[:,195:210]=0 # заменяет нулями 47-й(27-й) зуб во всех кейсах батча, от этого корежится предикт
        # удаляем нули
        # for item in T1
        # print(X[3])
        # синтезируем лендмарки, если их нет.
        T1 = T1.to(device)
        T2 = T2.to(device)   
        pred = model(T1)
        break  # достаточно первого батча, нет необходимости по всем шариться.
# _loader.__len__()
print(f" pred.__len__() = {pred.__len__()}")
#size = len(train_loader.dataset)
# Out:
# loader batch size = 2048 batches in it = 1
#  pred.__len__() = 97

# %%
# %matplotlib qt
# %matplotlib widget
# import ipywidgets as widgets

# класс генератора искусственных лендмарков нужен чтобы использовать его метод для рисовки графиков
inst_ = Landmark_gen()
T1=T1.to("cpu")
T2=T2.to("cpu")
pred = pred.to("cpu")
T1 = np.reshape(T1,              (-1, n_teeth, inp_dim//n_teeth))
T2 = np.reshape(T2,              (-1, n_teeth, inp_dim//n_teeth))
pred = np.reshape(pred,            (-1, n_teeth, inp_dim//n_teeth))
print(f"T2 {T2}")
print(f"pred {pred}")
# pred = pred[:,:12,:]

#  убираем вторые моляры в челюсти T2 (это просто тесты)
# T2e = T2.clone().detach() # copy tensor
# T2e[:,0,:]=0
# T2e[:,13,:]=0

k = 4  # колво графиков больше 20 не надо - не рисует
m = 1  # кейсов на графике
sft = 0  # сдвиг от начала датасета
# assert n>=m*k+sft

for i in range(k):
    inst_.draw_3d(
                    #T1[i*m+sft:(i+1)*m+sft],  # входные       T1
                  T2[i*m+sft:(i+1)*m+sft],  # тренировочные T2
                  pred[i*m+sft:(i+1)*m+sft],  # предиктные    T2
                  # h - горизонтальное расположение графиков, v - верт(дефолт)
                  style='h',
                  show=True)
# Out:
# T2 tensor([[[22.7100, 14.1100,  0.1200,  ..., 26.4900, 20.4700, -2.1800],
#          [22.4900,  3.8600, -1.2000,  ..., 26.4300, 10.1500, -5.7800],
#          [19.1100, -3.2600, -0.8300,  ..., 22.9400, -0.3300, -6.0900],
#          ...,
#          [26.6400, 17.0900,  0.3100,  ..., 27.5200, 21.1400,  5.4100],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#         [[23.7700, 13.8900, -0.7800,  ..., 29.1200, 20.6400, -3.6800],
#          [21.9900,  2.3100, -1.2300,  ..., 27.2000,  9.2300, -6.5800],
#          [19.4900, -4.8000, -0.3300,  ..., 23.4700, -0.7600, -7.2600],
#          ...,
#          [27.3600, 13.6100, -2.6600,  ..., 29.1600, 16.5900,  5.1700],
#          [29.4200, 19.6900,  5.6400,  ..., 31.2900, 20.4200,  8.6700],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#         [[23.5000, 13.3600, -0.3200,  ..., 27.2700, 17.6800, -6.2800],
#          [23.7000,  2.5400,  0.1300,  ..., 26.6000,  7.1800, -6.5600],
#          [19.8600, -4.4900, -0.0500,  ..., 23.1100, -2.1500, -7.1200],
#          ...,
#          [26.8100, 14.8400, -2.0200,  ..., 29.3900, 19.0600,  4.4200],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#         ...,
#
#         [[27.7900, 21.4400,  1.5800,  ..., 31.3700, 24.9400,  0.6600],
#          [26.1200,  9.8000, -0.3300,  ..., 29.8700, 16.1600, -4.4600],
#          [23.4800, -1.1400, -0.0500,  ..., 27.6700,  4.5900, -4.9900],
#          ...,
#          [27.6800,  1.3900, -0.8800,  ..., 30.0200,  6.0300,  4.5400],
#          [29.8800, 11.4800, -0.7800,  ..., 31.5700, 15.5900,  4.9100],
#          [31.2800, 20.3300,  2.0900,  ..., 33.1200, 24.0500,  3.4400]],
#
#         [[26.4500, 14.3500, -1.0000,  ..., 31.2800, 21.0000, -5.5800],
#          [23.9300,  2.4100, -1.3400,  ..., 28.1100,  9.0200, -7.7600],
#          [20.8000, -4.7500, -0.9200,  ..., 24.2900, -1.2000, -9.5000],
#          ...,
#          [28.9900, 12.3500, -3.1900,  ..., 33.1100, 15.4100,  5.9000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#         [[23.9300, 17.5700, -0.5900,  ..., 27.8300, 20.2700, -1.4600],
#          [24.4900,  7.2900, -1.3900,  ..., 28.4100, 13.0400, -5.2100],
#          [18.6400, -7.7100, -0.2700,  ..., 22.8000, -4.4200, -6.2400],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]])
# pred tensor([[[ 2.3150e+01,  1.3718e+01,  1.6445e-01,  ...,  2.6753e+01,
#            1.9959e+01, -2.9614e+00],
#          [ 2.2720e+01,  2.4737e+00, -3.4920e-01,  ...,  2.6515e+01,
#            8.1787e+00, -5.1285e+00],
#          [ 1.9490e+01, -4.9130e+00, -2.2020e-01,  ...,  2.3086e+01,
#           -1.4780e+00, -5.8516e+00],
#          ...,
#          [ 2.6845e+01,  1.5951e+01,  8.4032e-02,  ...,  2.8540e+01,
#            2.0174e+01,  5.7193e+00],
#          [ 7.1012e-02,  2.9329e-01,  3.8151e-02,  ...,  1.9899e-02,
#            3.2368e-01,  3.0574e-02],
#          [-1.4683e-02,  1.2092e-01, -1.5645e-01,  ..., -3.4779e-01,
#            2.3569e-01,  3.2480e-02]],
#
#         [[ 2.4449e+01,  1.4818e+01, -1.0316e-01,  ...,  2.8231e+01,
#            2.0968e+01, -3.8596e+00],
#          [ 2.3354e+01,  4.4966e+00, -7.0024e-01,  ...,  2.7260e+01,
#            1.0857e+01, -5.1659e+00],
#          [ 2.0074e+01, -3.4792e+00, -8.7687e-02,  ...,  2.4332e+01,
#           -1.7402e-01, -5.7899e+00],
#          ...,
#          [ 2.7158e+01,  1.5639e+01, -9.1249e-01,  ...,  2.9300e+01,
#            1.9247e+01,  5.3049e+00],
#          [ 2.8375e+01,  2.3353e+01,  3.0450e+00,  ...,  2.9143e+01,
#            2.6607e+01,  7.4795e+00],
#          [ 4.7960e-02,  2.7454e-01,  3.5855e-02,  ...,  4.0999e-03,
#            4.0763e-01, -6.6083e-02]],
#
#         [[ 2.4654e+01,  1.3348e+01, -1.3341e+00,  ...,  2.8258e+01,
#            1.9137e+01, -5.6955e+00],
#          [ 2.3129e+01,  2.5145e+00, -1.1347e+00,  ...,  2.6786e+01,
#            7.2219e+00, -6.1257e+00],
#          [ 1.9468e+01, -3.8107e+00, -5.1963e-02,  ...,  2.3505e+01,
#           -1.3383e+00, -6.7990e+00],
#          ...,
#          [ 2.7846e+01,  1.5615e+01, -1.0441e+00,  ...,  2.9927e+01,
#            2.0083e+01,  4.3570e+00],
#          [-1.0203e-01,  7.8242e-02, -2.3055e-01,  ...,  5.4691e-02,
#           -2.1852e-01,  1.8435e-02],
#          [-4.5414e-03, -1.5001e-01,  1.1849e-01,  ...,  2.1708e-01,
#           -3.2591e-01,  9.3605e-03]],
#
#         ...,
#
#         [[ 2.5682e+01,  2.1102e+01,  1.1497e+00,  ...,  2.9477e+01,
#            2.6531e+01, -8.7954e-01],
#          [ 2.4988e+01,  1.0618e+01,  2.8414e-03,  ...,  2.8839e+01,
#            1.7286e+01, -4.2327e+00],
#          [ 2.4266e+01, -2.4097e-01,  7.2315e-02,  ...,  2.7759e+01,
#            4.8039e+00, -5.5393e+00],
#          ...,
#          [ 2.7198e+01,  1.4180e+00, -5.7422e-01,  ...,  2.9791e+01,
#            6.0668e+00,  5.3383e+00],
#          [ 2.8408e+01,  1.2295e+01, -3.5506e-01,  ...,  3.0620e+01,
#            1.6955e+01,  6.0006e+00],
#          [ 2.9242e+01,  2.2020e+01,  1.5719e+00,  ...,  3.0169e+01,
#            2.6015e+01,  6.4536e+00]],
#
#         [[ 2.6177e+01,  1.4382e+01, -1.6084e-01,  ...,  3.0357e+01,
#            2.1065e+01, -4.2271e+00],
#          [ 2.4909e+01,  2.3985e+00, -7.1738e-01,  ...,  2.9166e+01,
#            8.9746e+00, -6.1560e+00],
#          [ 2.1689e+01, -5.2803e+00, -6.5328e-01,  ...,  2.5583e+01,
#           -1.8427e+00, -6.8623e+00],
#          ...,
#          [ 2.9077e+01,  1.4511e+01, -6.1796e-01,  ...,  3.1532e+01,
#            1.8911e+01,  6.1386e+00],
#          [ 1.2281e-01, -2.3340e-01,  1.0863e-01,  ...,  1.4956e-01,
#           -5.7720e-02, -5.5435e-02],
#          [ 1.1341e-01,  1.3329e-01,  1.1765e-01,  ...,  1.0119e-01,
#           -1.8916e-02,  1.0084e-01]],
#
#         [[ 2.4767e+01,  1.4973e+01, -2.0715e+00,  ...,  2.8031e+01,
#            2.0746e+01, -6.8538e+00],
#          [ 2.1754e+01,  1.4536e+00,  1.6629e+00,  ...,  2.6763e+01,
#            6.5571e+00, -1.0430e+01],
#          [ 2.0050e+01, -7.3389e+00, -6.5166e-01,  ...,  2.2166e+01,
#           -1.8991e+00, -9.2094e+00],
#          ...,
#          [ 2.2184e+00, -1.8184e+00, -4.4580e-01,  ...,  7.8578e-02,
#           -9.4662e-02, -6.3604e-01],
#          [ 4.3243e-03, -5.5918e-02, -2.0473e+00,  ...,  6.7921e-01,
#            2.0432e+00,  6.5840e-01],
#          [-1.0052e-01, -5.4131e-01, -1.6350e-01,  ..., -1.1701e+00,
#           -9.5516e-01, -1.3758e+00]]])

# %%
def train_loop_encoder(train_loader, test_loader, model, loss_fn, optimizer, t):

    for batch, (X, y) in enumerate(train_loader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        writer.add_scalar("Loss/train", loss, t)
        optimizer.step()

    loss = loss.item()

    for batch_t, (Xt, yt) in enumerate(test_loader):
        pred_t = model(Xt)
        loss_t = loss_fn(pred_t, yt)
        writer.add_scalar("Loss/test", loss_t, t)

    loss_t = loss_t.item()

    if t % 100 == 0:
        # loss, current = loss.item(), batch * len(X)
        print(f"Epoch {t} - loss {loss:.5}  /  val loss {loss_t:.5}")

    if (t > 100) & (loss_t < min(loss_min)):  # работаем по test loss
        loss_min.append(loss_t)
        # print(f"Ep: {t+1}  loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
        print(f"Ep: {t+1}  loss: {loss:>7f}  /  val loss {loss_t:.5}")
        if (t > 100):
            torch.save(
                model, f"{models_dir}/autoencoder_Epoch_{t}_loss_{loss_t:.5}.pth")
            print(f"Saved {t+1}")

    # print(f"loss: {loss:>7f}  [{current:>5d}")

# %%
# model params calc
from prettytable import PrettyTable


def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad:
            continue
        params = parameter.numel()
        table.add_row([name, params])
        total_params += params
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# count_parameters(model)
